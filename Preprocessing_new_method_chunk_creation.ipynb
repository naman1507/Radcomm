# %%
#This code will extract text from .docx file of 3GPP

# %%
import os
from docx import Document

def preprocess_docx(docx_path, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Load the Word document
    doc = Document(docx_path)

    # Flag to determine whether to skip content
    skip_content = False

    output_text_path = os.path.join(output_folder, "extracted_text.txt")

    with open(output_text_path, "w", encoding="utf-8") as output_file:
        for i, paragraph in enumerate(doc.paragraphs):
            # Check if the starting or ending lines are present in the paragraph
            if "3rd Generation Partnership Project (3GPP TM)" in paragraph.text:
                skip_content = True
                continue
            elif "All rights reserved." in paragraph.text:
                skip_content = False
                continue

            # Skip content if the flag is True
            if skip_content:
                continue

            # Process text as it is
            text = paragraph.text + "\n"
            output_file.write(text)
            print(text)

    print(f"Extracted text saved to: {output_text_path}")

# Example usage
docx_path = r'/Users/aadivikram/Desktop/3GPP_extracted/Rel-18/33_series/33128-i40.docx'
output_folder = r'/Users/aadivikram/Desktop/3GPP_extracted/output_p'
preprocess_docx(docx_path, output_folder)
# Out:
# 3GPP TS 33.128 V18.4.0 (2023-06)
#
# Technical Specification
#
# 3rd Generation Partnership Project;
#
# Technical Specification Group Services and System Aspects;
#
# Security;
#
# Protocol and procedures for Lawful Interception (LI);
#
# Stage 3
#
# (Release 18)
#
#
#
#
#
#
#
#
#
#
#
#
# Keywords
#
# 5G, 4G, 3G, Security, LI, Protocol, Procedures
#
#
#
# 3GPP
#
# Postal address
#
#
#
# 3GPP support office address
#
# 650 Route des Lucioles - Sophia Antipolis
#
# Valbonne - FRANCE
#
# Tel.: +33 4 92 94 42 00 Fax: +33 4 93 65 47 16
#
# Internet
#
# https://www.3gpp.org
#
#
#
# Copyright Notification
#
# No part may be reproduced except as authorized by written permission.
# The copyright and the foregoing restriction extend to reproduction in all media.
#
#
#
# © 2023, 3GPP Organizational Partners (ARIB, ATIS, CCSA, ETSI, TSDSI, TTA, TTC).
#
#
#
# UMTS™ is a Trade Mark of ETSI registered for the benefit of its members
#
# 3GPP™ is a Trade Mark of ETSI registered for the benefit of its Members and of the 3GPP Organizational Partners
# LTE™ is a Trade Mark of ETSI registered for the benefit of its Members and of the 3GPP Organizational Partners
#
# GSM® and the GSM logo are registered and owned by the GSM Association
#
# Contents
#
# Foreword	17
#
# Introduction	17
#
# 1	Scope	18
#
# 2	References	18
#
# 3	Definitions, symbols and abbreviations	22
#
# 3.1	Definitions	22
#
# 3.2	Symbols	22
#
# 3.3	Abbreviations	23
#
# 4	General	24
#
# 4.1	Introduction	24
#
# 4.2	Basic principles for internal interfaces	25
#
# 4.3	Basic principles for external handover interfaces	26
#
# 4.4	Service scoping	27
#
# 4.4.1	General	27
#
# 4.4.2	CSP service type	27
#
# 4.4.3	Delivery type	27
#
# 4.4.4	Location Reporting	28
#
# 4.4.5	LALS Triggering	28
#
# 4.4.6	Roaming Interception	28
#
# 5	Transport and Communications Protocol	28
#
# 5.1	General	28
#
# 5.2	Protocols for LI_X1 and LI_T interfaces	28
#
# 5.2.1	General usage of ETSI TS 103 221-1	28
#
# 5.2.2	Usage for realising LI_X1	29
#
# 5.2.3	Usage for realising LI_X1 (management)	29
#
# 5.2.4	Service scoping	29
#
# 5.2.5	Usage for realising LI_T2	30
#
# 5.2.6	Usage for realising LI_T3	30
#
# 5.2.7	Usage for realising LI_XEM1	31
#
# 5.3	Protocols for LI_X2 and LI_X3	32
#
# 5.3.1	General usage of ETSI TS 103 221-2	32
#
# 5.3.2	Usage for realising LI_X2	32
#
# 5.3.3	Usage for realising LI_X3	32
#
# 5.3.4	Service scoping	33
#
# 5.3.5	Usage for realising LI_X2_LA	33
#
# 5.4	Protocols for LI_HI1	33
#
# 5.4.1	General	33
#
# 5.4.2	Service scoping	34
#
# 5.4.3	Location acquisition	34
#
# 5.5	Protocols for LI_HI2 and LI_HI3	34
#
# 5.5.1	General	34
#
# 5.5.2	Usage for realising LI_HI2	34
#
# 5.5.3	Usage for realising LI_HI3	35
#
# 5.5.4	Service scoping	35
#
# 5.5.5	IRI Target Identifiers	35
#
# 5.6	Protocols for LI_HI4	35
#
# 5.6.1	General	35
#
# 5.6.2	Usage for realising LI_HI4	36
#
# 5.7	Protocols for LI_HIQR	36
#
# 5.7.1	General	36
#
# 5.7.2	Usage for realising LI_HIQR	36
#
# 5.7.2.1	Request structure	36
#
# 5.7.2.2	Request parameters	37
#
# 5.7.2.3	Response structure	38
#
# 5.8	Protocols for LI_XQR	39
#
# 5.8.1	General	39
#
# 5.8.2	Identity association requests	40
#
# 5.8.3	Ongoing identity association requests	40
#
# 5.9	Protocols for LI_XER	40
#
# 5.10	Protocols for LI_ST interface	41
#
# 5.10.1	Overview	41
#
# 5.10.2	Storage	41
#
# 5.10.3	Retrieval	41
#
# 5.10.4	Removal	41
#
# 5.11	Protocols for LI_HILA	41
#
# 5.11.1	General	41
#
# 5.11.2	Usage for realising LI_HILA	42
#
# 5.11.2.1	Request structure	42
#
# 5.11.2.2	Request parameters	42
#
# 5.11.2.3	Response structure	43
#
# 5.12	Protocols for LI_XLA	43
#
# 5.12.1	General	43
#
# 5.12.2	Usage for realising LI_XLA	44
#
# 6	Network Layer Based Interception	44
#
# 6.1	Introduction	44
#
# 6.2	5G	45
#
# 6.2.1	General	45
#
# 6.2.2	LI at AMF	45
#
# 6.2.2.1	Provisioning over LI_X1	45
#
# 6.2.2.2	Generation of xIRI over LI_X2	46
#
# 6.2.2.2.1	General	46
#
# 6.2.2.2.2	Registration	46
#
# 6.2.2.2.3	Deregistration	47
#
# 6.2.2.2.4	Location update	48
#
# 6.2.2.2.5	Start of interception with registered UE	49
#
# 6.2.2.2.6	AMF unsuccessful procedure	50
#
# 6.2.2.2.7	AMF identifier association	51
#
# 6.2.2.2.8	Positioning info transfer	51
#
# 6.2.2.2.9	Handovers	52
#
# 6.2.2.2.10	UE Configuration Update	54
#
# 6.2.2.2.11	Trace	54
#
# 6.2.2.2.11.1	General	54
#
# 6.2.2.2.11.2	AMF RAN trace report	54
#
# 6.2.2.3	Generation of IRI over LI_HI2	55
#
# 6.2.2.4	Identity privacy	56
#
# 6.2.2A	Identifier Reporting for AMF	56
#
# 6.2.2A.1	Activation of reporting over LI_XEM1	56
#
# 6.2.2A.2	Generation of records over LI_XER	56
#
# 6.2.2A.2.2	Association Events	57
#
# 6.2.2A.2.3	Transmission to the ICF	58
#
# 6.2.3	LI for SMF/UPF	58
#
# 6.2.3.1	Provisioning over LI_X1	58
#
# 6.2.3.1.1	General	58
#
# 6.2.3.1.2	Provisioning of the IRI-POI, IRI-TF and CC-TF in the SMF	58
#
# 6.2.3.1.3	Provisioning of the MDF2	59
#
# 6.2.3.1.4	Provisioning of the MDF3	60
#
# 6.2.3.2	Generation of xIRI at IRI-POI in SMF over LI_X2	61
#
# 6.2.3.2.1	General	61
#
# 6.2.3.2.2	PDU session establishment	62
#
# 6.2.3.2.3	PDU session modification	67
#
# 6.2.3.2.4	PDU session release	69
#
# 6.2.3.2.5	Start of interception with an established PDU session	70
#
# 6.2.3.2.6	SMF unsuccessful procedure	74
#
# 6.2.3.2.7	MA PDU sessions	75
#
# 6.2.3.2.8	PDU to MA PDU session modification	88
#
# 6.2.3.3	Triggering of the CC-POI from CC-TF over LI_T3	89
#
# 6.2.3.3.1	LI_T3 interface specifics	89
#
# 6.2.3.3.2	CC interception with multi-homed PDU session	91
#
# 6.2.3.3.3	CC Interception only at PDU Session Anchor UPFs	92
#
# 6.2.3.4	IRI-POI in UPF triggering over LI_T2	92
#
# 6.2.3.5	Generation of xIRI at UPF over LI_X2	93
#
# 6.2.3.5.1	Packet data header reporting	93
#
# 6.2.3.5.2	Fragmentation	93
#
# 6.2.3.5.3	Packet Data Header Report (PDHR)	93
#
# 6.2.3.5.4	Packet Data Summary Report (PDSR)	93
#
# 6.2.3.6	Generation of xCC at CC-POI in the UPF over LI_X3	93
#
# 6.2.3.7	Generation of IRI over LI_HI2	94
#
# 6.2.3.8	Generation of CC over LI_HI3	95
#
# 6.2.3.9	Packet header information reporting	95
#
# 6.2.3.9.1	General	95
#
# 6.2.3.9.2	Provisioning details	96
#
# 6.2.3.9.3	PDHeaderReport record	96
#
# 6.2.3.9.4	PDSummaryReport record	97
#
# 6.2.3.10	Sharing LI state information over LI_ST	101
#
# 6.2.3.10.1	Overview	101
#
# 6.2.3.10.2	Storing LI state	101
#
# 6.2.3.10.3	Retrieving LI state	102
#
# 6.2.3.10.4	Removing LI state	102
#
# 6.2.4	LI at UDM for 5G	102
#
# 6.2.4.1	General description	102
#
# 6.2.5	LI at SMSF	102
#
# 6.2.5.1	Provisioning over LI_X1	102
#
# 6.2.5.2	Generation of xIRI over LI_X2	104
#
# 6.2.5.3	SMS Message	104
#
# 6.2.5.4	Generation of IRI over LI_HI2	107
#
# 6.2.6	LI support at NRF	107
#
# 6.3	4G	107
#
# 6.3.1	General	107
#
# 6.3.2	LI at MME	108
#
# 6.3.2.1	Provisioning over LI_X1	108
#
# 6.3.2.2	Generation of xIRI over LI_X2	109
#
# 6.3.2.2.1	General	109
#
# 6.3.2.2.2	MME identifier association	109
#
# 6.3.2.2.3	Attach	110
#
# 6.3.2.2.4	Detach	111
#
# 6.3.2.2.5	Tracking Area/EPS Location update	112
#
# 6.3.2.2.6	Start of interception with EPS attached UE	113
#
# 6.3.2.2.7	MME unsuccessful procedure	114
#
# 6.3.2.2.8	Positioning info transfer	115
#
# 6.3.2.3	Generation of IRI over LI_HI2	116
#
# 6.3.2.3.1	General	116
#
# 6.3.2.3.2	Option A	116
#
# 6.3.2.3.3	Option B and Option C	117
#
# 6.3.3	LI at SGW/PGW and ePDG	117
#
# 6.3.3.0	General	117
#
# 6.3.3.1	Provisioning over LI_X1	117
#
# 6.3.3.1.1	General	117
#
# 6.3.3.1.2	Non-CUPS Architecture	118
#
# 6.3.3.1.3	CUPS Architecture	119
#
# 6.3.3.1.4	Provisioning of the MDF2	119
#
# 6.3.3.1.5	Provisioning of the MDF3	120
#
# 6.3.3.2	Generation of xIRI over LI_X2	121
#
# 6.3.3.2.1	General	121
#
# 6.3.3.2.2	PDU Session Establishment message reporting PDU session establishment or PDN Connection establishment	121
#
# 6.3.3.2.3	PDU Session Modification message reporting PDU session modification, PDN Connection modification or inter-system handover	127
#
# 6.3.3.2.4	PDU Session Release message reporting PDU session release, PDN Connection release	132
#
# 6.3.3.2.5	SMF Start of Interception with Already Established PDU Session message reporting Start of Interception with Already Established PDU Session or Start of Interception with Already Established PDN Connection	133
#
# 6.3.3.2.6	MA PDU Session Establishment message reporting MA PDU session establishment or PDN Connection establishment as part of an MA PDU Session	135
#
# 6.3.3.2.7	MA PDU Session Modification message reporting MA PDU session modification, modification of a PDN Connection associated to MA PDU session or inter-system handover	135
#
# 6.3.3.2.8	MA PDU Session Release message reporting MA PDU session release or the release of a PDN Connection associated to an MA PDU session	136
#
# 6.3.3.2.9	SMF Start of Interception with Already Established MA PDU Session message reporting Start of Interception with Already Established MA PDU Session or Start of Interception with Already Established PDN Connection associated to an MA PDU Session	136
#
# 6.3.3.2A	Triggering of the CC-POI from CC-TF over LI_T3	137
#
# 6.3.3.3	Generation of xCC at CC-POI in the SGW/PGW and ePDG over LI_X3	137
#
# 6.3.3.3.1	Non-CUPS architecture	137
#
# 6.3.3.3.2	CUPS architecture	137
#
# 6.3.3.4	Generation of IRI over LI_HI2	137
#
# 6.3.3.5	Generation of CC over LI_HI3	138
#
# 6.4	3G	138
#
# 7	Service Layer Based Interception	138
#
# 7.1	Introduction	138
#
# 7.2	Central Subscriber Management	138
#
# 7.2.1	General description	138
#
# 7.2.2	LI at UDM	138
#
# 7.2.2.1	General description	138
#
# 7.2.2.2	Provisioning over LI_X1	138
#
# 7.2.2.3	Generation of xIRI over LI_X2	139
#
# 7.2.2.3.1	General description	139
#
# 7.2.2.3.2	Serving system	139
#
# 7.2.2.3.3	Subscriber record change	139
#
# 7.2.2.3.4	Cancel location	141
#
# 7.2.2.3.5	Location information request	142
#
# 7.2.2.3.6	Location information result	142
#
# 7.2.2.3.7	UE information response	143
#
# 7.2.2.3.8	UE Authentication response	144
#
# 7.2.2.3.9	Start of Interception with UE registered at the UDM	145
#
# 7.2.2.4	Generation of IRI over LI_HI2	145
#
# 7.2.3	LI at HSS	145
#
# 7.2.3.1	General	145
#
# 7.2.3.2	 Provisioning over LI_X1	146
#
# 7.2.3.3	 Generation of xIRI over LI_X2	146
#
# 7.2.3.3.1	General description	146
#
# 7.2.3.3.2	Serving system	146
#
# 7.2.3.3.3	Start of Interception with target registered at the HSS	147
#
# 7.2.3.4	Generation of IRI over LI_HI2	147
#
# 7.3	Location	148
#
# 7.3.1	Lawful Access Location Services (LALS)	148
#
# 7.3.1.1	General description	148
#
# 7.3.1.2	Provisioning over LI_X1	148
#
# 7.3.1.2.1	Target positioning service	148
#
# 7.3.1.2.2	Triggered location service	149
#
# 7.3.1.3	Triggering over LI_T2	149
#
# 7.3.1.4	Generation of xIRI over LI_X2	150
#
# 7.3.1.5	Generation of IRI over LI_HI2	151
#
# 7.3.2	Cell database information reporting	151
#
# 7.3.2.1	General description	151
#
# 7.3.2.2	Delivery of cell site information over LI_HI2	151
#
# 7.3.3	Use of the Location structure	152
#
# 7.3.3.1	General description	152
#
# 7.3.3.2	Location structure data types	153
#
# 7.3.3.2.1	Simple data types for location	153
#
# 7.3.3.2.2	Type: Location	156
#
# 7.3.3.2.3	Type: LocationInfo	157
#
# 7.3.3.2.4	Type: UserLocation	158
#
# 7.3.3.2.5	Type: EUTRALocation	159
#
# 7.3.3.2.6	Type: NRLocation	160
#
# 7.3.3.2.7	Type: N3GALocation	161
#
# 7.3.3.2.8	Type: UTRALocation	162
#
# 7.3.3.2.9	Type: GERALocation	163
#
# 7.3.3.2.10	Type: GeographicArea	164
#
# 7.3.3.2.11	Type: Point	165
#
# 7.3.3.2.12	Type: geoCoord	165
#
# 7.3.3.2.13	Type: PointUncertaintyCircle	165
#
# 7.3.3.2.14	Type: PointUncertaintyEllipse	166
#
# 7.3.3.2.15	Type: UncertaintyEllipse	166
#
# 7.3.3.2.16	Type: Polygon	166
#
# 7.3.3.2.17	Type: PointAltitude	167
#
# 7.3.3.2.18	Type: PointAltitudeUncertainty	167
#
# 7.3.3.2.19	Type: EllipsoidArc	167
#
# 7.3.3.2.20	Enumeration: RATType	168
#
# 7.3.3.2.21	Type: CellInformation	168
#
# 7.3.3.2.22	Type: RANCGI	168
#
# 7.3.3.2.23	Type: TAI	168
#
# 7.3.3.2.24	Type: ECGI	169
#
# 7.3.3.2.25	Type: GlobalRANNodeID	169
#
# 7.3.3.2.26	Type: ANNodeID	169
#
# 7.3.3.2.27	Type: NgENBID	170
#
# 7.3.3.2.28	Type: NCGI	170
#
# 7.3.3.2.29	Type: IPAddr	170
#
# 7.3.3.2.30	Type: TNAPID	171
#
# 7.3.3.2.31	Type: TWAPID	171
#
# 7.3.3.2.32	Enumeration: W5GBANLineType	171
#
# 7.3.3.2.33	Enumeration: TransportProtocol	172
#
# 7.3.3.2.34	Type: PLMNID	172
#
# 7.3.3.2.35	Type: ENbID	172
#
# 7.3.3.2.36	Type: PositioningInfo	172
#
# 7.3.3.2.37	Type: LocationData	173
#
# 7.3.3.2.38	Type: RawMLPResponse	174
#
# 7.3.3.2.39	Type: VelocityEstimate	175
#
# 7.3.3.2.40	Type: CivicAddress	175
#
# 7.3.3.2.41	Type: PositioningMethodAndUsage	177
#
# 7.3.3.2.42	Type: GNSSPositioningMethodAndUsage	177
#
# 7.3.3.2.43	Type: HorizontalVelocity	177
#
# 7.3.3.2.44	Type: HorizontalWithVerticalVelocity	177
#
# 7.3.3.2.45	Type: HorizontalVelocityWithUncertainty	178
#
# 7.3.3.2.46	Type: HorizontalWithVerticalVelocityAndUncertainty	178
#
# 7.3.3.2.47	Type: LocationPresenceReport	178
#
# 7.3.3.2.48	Type: AMFEventArea	179
#
# 7.3.3.2.49	Type: RMInfo	179
#
# 7.3.3.2.50	Type: CMInfo	180
#
# 7.3.3.2.51	Enumeration: AccuracyFulfilmentIndicator	180
#
# 7.3.3.2.52	Enumeration: PositioningMethod	180
#
# 7.3.3.2.53	Enumeration: PositioningMode	181
#
# 7.3.3.2.54	Enumeration: GNSSID	181
#
# 7.3.3.2.55	Enumeration: Usage	181
#
# 7.3.3.2.56	Enumeration: VerticalDirection	182
#
# 7.3.3.2.57	Type: IMSLocation	182
#
# 7.3.3.2.58	Type: PANIHeaderInfo	182
#
# 7.3.3.2.59	Type: SIPGeolocationHeaderInfo	183
#
# 7.3.3.2.60	Type: SIPLocationInfo	183
#
# 7.3.3.2.61	Type: SIPCNIHeaderInfo	183
#
# 7.3.3.2.62	Type: PresenceInfo	184
#
# 7.3.3.2.63	Type: LADNInfo	184
#
# 7.3.3.2.64	 Enumeration: AMFEventType	185
#
# 7.3.3.2.65	 Enumeration: AccessType	185
#
# 7.3.3.2.66	 Enumeration: UEReachability	185
#
# 7.3.3.2.67	Enumeration: RMState	185
#
# 7.3.3.2.68	Enumeration: CMState	186
#
# 7.3.3.2.69	Enumeration: PresenceState	186
#
# 7.3.3.2.70	Type: FourGPositioningInfo	186
#
# 7.3.3.2.71	Type: FourGLocationInfo	187
#
# 7.3.3.2.72	Type: CGI	187
#
# 7.3.3.2.73	Type: SAI	188
#
# 7.3.3.2.74	Type: ESMLCCellInfo	188
#
# 7.3.3.2.75	Type: GERANPositioningInfo	188
#
# 7.3.3.2.76	Type: UTRANPositioningInfo	189
#
# 7.3.3.2.77	Type: EPSLocationInformation	189
#
# 7.3.3.2.78	Type: MMELocationInformation	189
#
# 7.3.3.2.79	Type: SGSNLocationInformation	190
#
# 7.3.3.2.80	Type: UserCSGInformation	191
#
# 7.3.3.2.81	Type: LAI	191
#
# 7.3.3.2.82	Type: RAI	192
#
# 7.3.3.2.83	Enumeration: CSGAccessMode	192
#
# 7.3.3.2.84	Enumeration: CSGMembershipIndication	192
#
# 7.3.3.3	 Reference datum	192
#
# 7.3.4	Separated location reporting	193
#
# 7.3.4.1	General description	193
#
# 7.3.5	Location acquisition	193
#
# 7.3.5.1	General description	193
#
# 7.3.5.2	Acquisition request over LI_HILA	194
#
# 7.3.5.3	Acquisition request over LI_XLA	194
#
# 7.3.5.4	Location acquisition procedure at the LARF	194
#
# 7.3.5.4.1	General description	194
#
# 7.3.5.4.2	Location acquisition procedure at the LARF in case of EPC	194
#
# 7.3.5.4.3	Location acquisition procedure at the LARF in case of 5GC	194
#
# 7.3.5.5	Location acquisition delivery via the LI_HILA	194
#
# 7.3.5.5.1	Location acquisition response over LI_XLA	194
#
# 7.3.5.5.2	Location acquisition response over LI_HILA	195
#
# 7.3.5.6	Location acquisition delivery via the LI_HI2	195
#
# 7.3.5.6.1	Provisioning of the MDF2	195
#
# 7.3.5.6.2	LI_X2_LA delivery	196
#
# 7.3.5.6.3	LI_HI2 delivery	196
#
# 7.3.6	Location Only Reporting	196
#
# 7.3.6.1	General Information	196
#
# 7.3.6.2	Provisioning Information	196
#
# 7.3.6.3	Generation of Location Only xIRI	197
#
# 7.3.6.3.1	General	197
#
# 7.3.6.3.2	Location Only xIRI in 5GS	197
#
# 7.3.6.3.3	Location Only xIRI in EPS	197
#
# 7.3.6.4	Generation of Location Only IRI	197
#
# 7.4	Messaging	198
#
# 7.4.1	Introduction	198
#
# 7.4.2	LI at the MMS Proxy-Relay	198
#
# 7.4.2.1	Provisioning over LI_X1	198
#
# 7.4.2.2	Generation of xIRI over LI_X2	198
#
# 7.4.2.3	Generation of xCC over LI_X3	198
#
# 7.4.2.4	MMS Record Generation Cases	198
#
# 7.4.3	MMS Records	199
#
# 7.4.3.1	MMSSend	199
#
# 7.4.3.2	MMSSendByNonLocalTarget	201
#
# 7.4.3.3	MMSNotification	203
#
# 7.4.3.4	MMSSendToNonLocalTarget	203
#
# 7.4.3.5	MMSNotificationResponse	205
#
# 7.4.3.6	MMSRetrieval	205
#
# 7.4.3.7	MMSDeliveryAck	207
#
# 7.4.3.8	MMSForward	207
#
# 7.4.3.9	MMSDeleteFromRelay	209
#
# 7.4.3.10	MMSMBoxStore	210
#
# 7.4.3.11	MMSMBoxUpload	210
#
# 7.4.3.12	MMSMBoxDelete	211
#
# 7.4.3.13	MMSDeliveryReport	211
#
# 7.4.3.14	MMSDeliveryReportNonLocalTarget	212
#
# 7.4.3.15	MMSReadReport	213
#
# 7.4.3.16	MMSReadReportNonLocalTarget	214
#
# 7.4.3.17	MMSCancel	215
#
# 7.4.3.18	MMSMBoxViewRequest	215
#
# 7.4.3.19	MMSMBoxViewResponse	216
#
# 7.4.3.20	MMBoxDescription	217
#
# 7.4.3.21	MMS Content	219
#
# 7.4.4	IRI and CC Generation	219
#
# 7.4.4.1	Generation of IRI over LI_HI2	219
#
# 7.4.4.2	Generation of CC over LI_HI3	219
#
# 7.5	PTC service	219
#
# 7.5.1	Introduction	219
#
# 7.5.1.1	Provisioning over LI_X1	220
#
# 7.5.1.2	Generating xIRI over LI_X2	220
#
# 7.5.1.3	Generation of xCC over LI_X3	220
#
# 7.5.2	IRI events	220
#
# 7.5.2.1	PTC registration	220
#
# 7.5.2.2	PTC session initiation	220
#
# 7.5.2.3	PTC session abandon attempt	221
#
# 7.5.2.4	PTC session start	222
#
# 7.5.2.5	PTC session end	223
#
# 7.5.2.6	PTC start of interception	224
#
# 7.5.2.7	PTC pre-established session	225
#
# 7.5.2.8	PTC instant personal alert	225
#
# 7.5.2.9	PTC party join	225
#
# 7.5.2.10	PTC party drop	226
#
# 7.5.2.11	PTC party hold	227
#
# 7.5.2.12	PTC media modification	227
#
# 7.5.2.13	PTC group advertisement	228
#
# 7.5.2.14	PTC floor control	228
#
# 7.5.2.15	PTC target presence	230
#
# 7.5.2.16	PTC participant presence	231
#
# 7.5.2.17	PTC list management	231
#
# 7.5.2.18	PTC access policy	232
#
# 7.5.3	IRI and CC Generation	233
#
# 7.5.3.1	Generation of IRI over LI_HI2	233
#
# 7.5.3.2	Generation of CC over LI_HI3	234
#
# 7.6	Identifier Association Reporting	234
#
# 7.6.1	General	234
#
# 7.6.2	ICF	234
#
# 7.6.2.1	General	234
#
# 7.6.2.2	ICF receipt of records over LI_XER	234
#
# 7.6.2.3	ICF Query and Response over LI_XQR	234
#
# 7.6.2.4	ICF Identifier Association Event Handling	234
#
# 7.6.3	IQF	235
#
# 7.6.3.1	General	235
#
# 7.6.3.2	IQF Query and Response over LI_HIQR	236
#
# 7.6.3.3	IQF Query and Response over LI_XQR	236
#
# 7.7	LI at NEF	236
#
# 7.7.1	Provisioning over LI_X1	236
#
# 7.7.1.1	General	236
#
# 7.7.1.2	Provisioning of the IRI-POI and CC-POI in NEF	236
#
# 7.7.2	LI for NIDD using NEF	237
#
# 7.7.2.1	Generation of xIRI at IRI-POI in NEF over LI_X2	237
#
# 7.7.2.1.1	General	237
#
# 7.7.2.1.2	PDU session establishment	237
#
# 7.7.2.1.3	PDU session modification	237
#
# 7.7.2.1.4	PDU session release	238
#
# 7.7.2.1.5	Unsuccessful procedure	238
#
# 7.7.2.1.6	Start of interception with established PDU session	239
#
# 7.7.2.2	Generation of xCC at CC-POI in NEF over LI_X3	240
#
# 7.7.2.3	Generation of IRI over LI_HI2	240
#
# 7.7.2.4	Generation of CC over LI_HI3	240
#
# 7.7.3	LI for device triggering	240
#
# 7.7.3.1	Generation of xIRI LI_X2 at IRI-POI in NEF over LI_X2	240
#
# 7.7.3.1.1	General	240
#
# 7.7.3.1.2	Device trigger	240
#
# 7.7.3.1.3	Device trigger replace	241
#
# 7.7.3.1.4	Device trigger cancellation	241
#
# 7.7.3.1.5	Device trigger report notification	242
#
# 7.7.3.2	Generation of IRI over LI_HI2	242
#
# 7.7.4	LI for MSISDN-less MO SMS	243
#
# 7.7.4.1	Generation of xIRI LI_X2 at IRI-POI in NEF over LI_X2	243
#
# 7.7.4.1.1	General	243
#
# 7.7.4.1.2	MSISDN-less MO SMS	243
#
# 7.7.4.2	Generation of IRI over LI_HI2	243
#
# 7.7.5	LI for parameter provisioning	244
#
# 7.7.5.1	Generation of xIRI LI_X2 at IRI-POI in NEF over LI_X2	244
#
# 7.7.5.1.1	General	244
#
# 7.7.5.1.2	Expected UE behavior update	244
#
# 7.7.5.2	Generation of IRI over LI_HI2	245
#
# 7.7.6	LI for AF session with QoS	245
#
# 7.7.6.1	Generation of xIRI at IRI-POI in NEF over LI_X2	245
#
# 7.7.6.1.1	General	245
#
# 7.7.6.1.2	AF session with QoS provision	245
#
# 7.7.6.1.3	AF session with QoS notification	246
#
# 7.7.6.2	Generation of IRI over LI_HI2	246
#
# 7.8	LI at SCEF	247
#
# 7.8.1	Provisioning over LI_X1	247
#
# 7.8.1.1	General	247
#
# 7.8.1.2	Provisioning of the IRI-POI and CC-POI in SCEF	247
#
# 7.8.2	LI for NIDD using SCEF	247
#
# 7.8.2.1	Generation of xIRI at IRI-POI in SCEF over LI_X2	247
#
# 7.8.2.1.1	General	247
#
# 7.8.2.1.2	SCEF PDN connection establishment	247
#
# 7.8.2.1.3	PDN connection update	248
#
# 7.8.2.1.4	PDN connection release	249
#
# 7.8.2.1.5	Unsuccessful procedure	250
#
# 7.8.2.1.6	Start of interception with established PDN connection	251
#
# 7.8.2.2	Generation of xCC at CC-POI in SCEF over LI_X3	251
#
# 7.8.2.3	Generation of IRI over LI_HI2	252
#
# 7.8.2.4	Generation of CC over LI_HI3	252
#
# 7.8.3	LI for device triggering	252
#
# 7.8.3.1	Generation of xIRI LI_X2 at IRI-POI in SCEF over LI_X2	252
#
# 7.8.3.1.1	General	252
#
# 7.8.3.1.2	Device trigger	252
#
# 7.8.3.1.3	Device trigger replacement	253
#
# 7.8.3.1.4	Device trigger cancellation	253
#
# 7.8.3.1.5	Device trigger report notification	254
#
# 7.8.3.2	Generation of IRI over LI_HI2	254
#
# 7.8.4	LI for MSISDN-less MO SMS	255
#
# 7.8.4.1	Generation of xIRI LI_X2 at IRI-POI in SCEF over LI_X2	255
#
# 7.8.4.1.1	General	255
#
# 7.8.4.1.2	MSISDN-less MO SMS	255
#
# 7.8.4.2	Generation of IRI over LI_HI2	255
#
# 7.8.5	LI for parameter provisioning	256
#
# 7.8.5.1	Generation of xIRI LI_X2 at IRI-POI in SCEF over LI_X2	256
#
# 7.8.5.1.1	General	256
#
# 7.8.5.1.2	Communication pattern update	256
#
# 7.8.5.2	Generation of IRI over LI_HI2	257
#
# 7.8.6	LI for AS session with QoS	257
#
# 7.8.6.1	Generation of xIRI at IRI-POI in SCEF over LI_X2	257
#
# 7.8.6.1.1	General	257
#
# 7.8.6.1.2	AS session with QoS provision	258
#
# 7.8.6.1.3	AS session with QoS notification	258
#
# 7.8.6.2	Generation of IRI over LI_HI2	259
#
# 7.9	LI for services encrypted by CSP-provided keys	259
#
# 7.9.1	LI for general AKMA-based service	259
#
# 7.9.1.1	General	259
#
# 7.9.1.2	Provisioning over LI_X1	259
#
# 7.9.1.2.1	General	259
#
# 7.9.1.2.2	Provisioning of the IRI-POI in AAnF	260
#
# 7.9.1.2.3	Triggering of the IRI-POI in AF	260
#
# 7.9.1.3	Generation of xIRI at IRI-POI in AAnF over LI_X2	261
#
# 7.9.1.3.1	General	261
#
# 7.9.1.3.2	AAnF Anchor Key Register	261
#
# 7.9.1.3.3	AAnF AKMA application key get	261
#
# 7.9.1.3.4	AAnF Start of intercept with established AKMA key material	261
#
# 7.9.1.3.5	AAnF AKMA context removal	262
#
# 7.9.1.4	Generation of xIRI at IRI-POI in generic SUPI-based AF using over LI_X2	262
#
# 7.9.1.4.1	General	262
#
# 7.9.1.4.2	AF Application key refresh	262
#
# 7.9.1.4.3	AF Start of intercept with established AKMA application key	262
#
# 7.9.1.4.4	AF Auxiliary security parameter establishment	263
#
# 7.9.1.4.5	AF Application key removal	263
#
# 7.9.1.5	Generation of IRI over LI_HI2	263
#
# 7.10	LI in VPLMN for IMS-based services with home-routed roaming	264
#
# 7.10.1	Background	264
#
# 7.10.2	Backward compatibility	265
#
# 7.10.3	HR LI Phase 1	265
#
# 7.10.3.1	Overview	265
#
# 7.10.3.2	Provisioning over LI_X1	265
#
# 7.10.3.2.1	General	265
#
# 7.10.3.2.2	Provisioning of BBIFF-C and BBIFF	265
#
# 7.10.3.2.3	Provisioning of LMISF-IRI	266
#
# 7.10.3.3	Generation of xIRI over LI_X2_LITE	266
#
# 7.10.3.3.1	General	266
#
# 7.10.3.3.2	N9HR LI	267
#
# 7.10.3.3.3	S8HR LI	268
#
# 7.10.3.4	LMISF-IRI handling of xIRIs received over LI_X2_LITE	270
#
# 7.10.3.4.1	Handling of xIRIs	270
#
# 7.10.3.4.2	Handling of the stored record	270
#
# 7.10.3.5	Triggering of BBIFF-U from BBIFF-C over LI_T3	270
#
# 7.10.3.5.1	General	270
#
# 7.10.3.5.2	N9HR LI	271
#
# 7.10.3.5.3	S8HR LI	271
#
# 7.10.3.6	Generation of xCC over LI_X3_LITE_S	272
#
# 7.10.3.6.1	BBIFF-U	272
#
# 7.10.3.6.2	BBIFF	273
#
# 7.10.3.6.3	X3 PDU format	273
#
# 7.10.3.7	LMISF-IRI handling of xCC received over LI_X3_LITE_S	273
#
# 7.10.4	HR LI Phase 2	273
#
# 7.10.4.1	Overview	273
#
# 7.10.4.2	Provisioning over LI_X1	274
#
# 7.10.4.2.1	General	274
#
# 7.10.4.2.2	Provisioning of LMISF-IRI	274
#
# 7.10.4.2.3	Provisioning of the MDF2	275
#
# 7.10.4.2.4	Provisioning of the MDF3	275
#
# 7.10.4.3	Generation of xIRI over LI_X2	276
#
# 7.10.4.3.1	General concepts	276
#
# 7.10.4.3.2	Target match	277
#
# 7.10.4.3.2.1	General	277
#
# 7.10.4.3.2.2	Service type of voice	277
#
# 7.10.4.3.2.3	Service type of messaging	277
#
# 7.10.4.3.3	xIRIs	278
#
# 7.10.4.4	Triggering of BBIFF-C from LMISF over LI_T1	278
#
# 7.10.4.4.1	General	278
#
# 7.10.4.4.2	N9HR LI	278
#
# 7.10.4.4.3	S8HR LI	279
#
# 7.10.4.5	Triggering of BBIFF-U from BBIFF-C over LI_T3	280
#
# 7.10.4.5.1	General	280
#
# 7.10.4.5.2	N9HR LI	280
#
# 7.10.4.5.3	S8HR LI	281
#
# 7.10.4.6	Generation of xCC over LI_X3_LITE_M	282
#
# 7.10.4.7	Generation of xCC over LI_X3	282
#
# 7.10.4.8	Correlation identifier	282
#
# 7.10.4.9	Generation of IRI over LI_HI2	283
#
# 7.10.4.10	Generation of CC over LI_HI3	283
#
# 7.11	STIR/SHAKEN and RCD/eCNAM	283
#
# 7.11.1	Provisioning over LI_X1	283
#
# 7.11.1.1	General	283
#
# 7.11.1.2	Provisioning of the IRI-POI in the IMS network functions	283
#
# 7.11.1.3	Provisioning of the MDF2	284
#
# 7.11.2	Generation of xIRI at IRI-POI in the IMS Network Functions over LI_X2	285
#
# 7.11.2.1	General	285
#
# 7.11.2.2	Signature generation	285
#
# 7.11.2.3	Signature validation	288
#
# 7.11.2.4	IMS Network Function that interacts with signing AS	289
#
# 7.11.2.5	IMS Network Function that interacts with the verification AS	290
#
# 7.11.3	Generation of IRI over LI_HI2	290
#
# 7.12	LI for IMS based services	290
#
# 7.12.1	General	290
#
# 7.12.2	Overview	291
#
# 7.12.2.1	General	291
#
# 7.12.2.2	Target type and target identifiers	291
#
# 7.12.2.3	Roaming considerations	291
#
# 7.12.2.4	Service specific aspects	292
#
# 7.12.2.4.1	General	292
#
# 7.12.2.4.2	LI for normal sessions	292
#
# 7.12.2.4.3	LI for redirected sessions	292
#
# 7.12.2.4.4	LI for conferencing	292
#
# 7.12.2.4.5	STIR/SHAKEN	292
#
# 7.12.2.4.6	RCD/eCNAM	293
#
# 7.12.2.5	Service scoping	293
#
# 7.12.2.5.1	General	293
#
# 7.12.2.5.2	LI for voice	293
#
# 7.12.2.5.3	LI for Messaging	294
#
# 7.12.2.5.4	LI for voice-mail	294
#
# 7.12.2.5.5	LI for RCS	294
#
# 7.12.2.5.6	LI for PTC service	294
#
# 7.12.2.5.7	LALS triggering	294
#
# 7.12.2.6	Location reporting	294
#
# 7.12.2.7	Deployment considerations	295
#
# 7.12.2.8	Identifying the intercepted IMS-based communications	295
#
# 7.12.2.8.1	General concepts	295
#
# 7.12.2.8.2	Target match	295
#
# 7.12.2.8.2.1	General	295
#
# 7.12.2.8.2.2	Session based IMS services	295
#
# 7.12.2.8.2.3	Session independent IMS services	296
#
# 7.12.2.9	Handling of correlation information	297
#
# 7.12.3	Provisioning over LI_X1	297
#
# 7.12.3.1	General	297
#
# 7.12.3.2	Provisioning of IRI-POI	298
#
# 7.12.3.2.1	Session-based IMS services	298
#
# 7.12.3.2.2	Session-independent IMS services	298
#
# 7.12.3.3	Provisioning of CC-TF	299
#
# 7.12.3.4	Provisioning of the MDF2	300
#
# 7.12.3.5	Provisioning of the MDF3	301
#
# 7.12.4	Generation of xIRIs over LI_X2	301
#
# 7.12.4.1	IRI-POIs in IMS signaling functions	301
#
# 7.12.4.1.1	General	301
#
# 7.12.4.1.2	IRI-POI in P-CSCF	302
#
# 7.12.4.1.2.1	Session-based IMS communications	302
#
# 7.12.4.1.2.2	Session-independent IMS communications	302
#
# 7.12.4.1.3	IRI-POI in S-CSCF	302
#
# 7.12.4.1.3.1	Session-based IMS communications	302
#
# 7.12.4.1.3.2	Session-independent IMS communications	303
#
# 7.12.4.1.4	IRI-POI in E-CSCF	303
#
# 7.12.4.1.5	IRI-POI in IBCF	303
#
# 7.12.4.1.5.1	Session-based IMS communications	303
#
# 7.12.4.1.5.2	Session-independent IMS communications	304
#
# 7.12.4.1.6	IRI-POI in MGCF	304
#
# 7.12.4.1.6.1	Session-based IMS communications	304
#
# 7.12.4.1.6.2	Session-independent IMS communications	304
#
# 7.12.4.1.7	IRI-POI in AS	304
#
# 7.12.4.1.7.1	Session-based IMS communications	304
#
# 7.12.4.1.7.2	Session-independent IMS communications	304
#
# 7.12.4.2	IMS records	304
#
# 7.12.4.2.1	IMS Message	304
#
# 7.12.4.2.2	Start of interception with Active IMS session	305
#
# 7.12.4.2.3	IMS CC Unavailable	306
#
# 7.12.4.3	IMS record parameters	307
#
# 7.12.4.3.1	Type: IMSPayload	307
#
# 7.12.4.3.2	 Enumeration: SessionDirection	307
#
# 7.12.4.3.3	 Enumeration: VoIPRoamingIndication	307
#
# 7.12.4.3.4	Type: SIPMessage	308
#
# 7.12.4.3.5	Type: SIPAccessNetworkInformation	308
#
# 7.12.4.3.6	Type: SIPCellularNetworkInformation	308
#
# 7.12.5	Triggering of CC-POI by CC-TF over LI_T3	308
#
# 7.12.5.1	CC-TFs in IMS signaling functions	308
#
# 7.12.5.1.1	General	308
#
# 7.12.5.1.2	CC-TF in P-CSCF	309
#
# 7.12.5.1.3	CC-TF in IBCF	309
#
# 7.12.5.1.4	CC-TF in MGCF	309
#
# 7.12.5.1.5	CC-TF in AS/MRFC	310
#
# 7.12.5.2	LI_T3 triggering details	310
#
# 7.12.5.2.1	 General	310
#
# 7.12.5.2.2	 Activation Task	311
#
# 7.12.5.2.2.1	Overview	311
#
# 7.12.5.2.2.2	Activation of CC-POI in IMS-AGW, TrGW, IM-MGW	312
#
# 7.12.5.2.2.3	 CC-POI in MRFP	315
#
# 7.12.5.2.2.4	Activation of CC-POI when media interceptions are done at both sides IMS media function	316
#
# 7.12.5.2.3	ModifyTask	318
#
# 7.12.5.2.4	DeactivateTask	319
#
# 7.12.6	Generation of xCC over LI_X3	319
#
# 7.12.6.1	General	319
#
# 7.12.6.2	Media capture	319
#
# 7.12.6.3	Payload format	320
#
# 7.12.6.4	Payload direction	320
#
# 7.12.6.5	SDP session description	320
#
# 7.12.6.6	Additional XID related information	321
#
# 7.12.7	Generation of IRI over LI_HI2	321
#
# 7.12.7.1	General	321
#
# 7.12.7.2	Handling of multiple instances of list of mediation details	321
#
# 7.12.7.3	Mid-session activation for additional warrants at MDF2	322
#
# 7.12.7.4	Location reporting	322
#
# 7.12.8	Generation of CC over LI_HI3	322
#
# 7.12.8.1	General	322
#
# 7.12.8.2	Handling of multiple instances of list of mediation details	322
#
# 7.12.8.3	Handling of additional XID related information	322
#
# 7.12.8.4	SDP session description	322
#
# 7.12.8.5	Mid-session activation for additional warrants at MDF3	323
#
# 7.12.9	Removal of unauthorised information from IMS record payloads	323
#
# 7.12.9.1	General	323
#
# 7.12.9.2	Removal of location information	323
#
# 7.12.9.2.1	General	323
#
# 7.12.9.2.2	P-Access-Network-Info location removal	323
#
# 7.12.9.2.3	Cellular-Network-Info location removal	323
#
# 7.12.9.2.4	Geolocation header location removal	324
#
# 7.12.9.2.5	Removal of location information from presence information	324
#
# 7.12.9.3	Removal of communications content	324
#
# 7.12.9.3.1	General	324
#
# 7.12.9.3.2	Removal of SMS content	324
#
# 7.12.9.3.3	Removal of text content	324
#
# 7.12.9.3.4	Removal of content from the Subject header field	324
#
# 7.13	RCS	324
#
# 7.13.1	Provisioning over LI_X1	324
#
# 7.13.1.1	General	324
#
# 7.13.1.2	Provisioning of the POIs and TFs in the RCS Server and the POIs in the HTTP Content Server and S-CSCF by the LIPF	325
#
# 7.13.1.3	Provisioning of the MDF2	325
#
# 7.13.1.4	Provisioning of the MDF3	326
#
# 7.13.2	Triggering of the IRI-POI and CC-POI in the HTTP Content Server	327
#
# 7.13.2.1	Triggering of the IRI-POI in the HTTP Content Server over LI_T2	327
#
# 7.13.2.1.1	LI_T2 interface Specifics	327
#
# 7.13.2.2	Triggering of the CC-POI in the HTTP Content Server over LI_T3	328
#
# 7.13.2.2.1	LI_T3 interface Specifics	328
#
# 7.13.3	Generation of xIRI at IRI-POI in the RCS Server over LI_X2	329
#
# 7.13.3.1	General	329
#
# 7.13.3.1.1	Introduction	329
#
# 7.13.3.1.2	Common parameters for RCS reporting	329
#
# 7.13.3.1.2.1	Simple types	329
#
# 7.13.3.1.2.2	Type: RCSIdentity	330
#
# 7.13.3.1.2.3	Type: RCSDestinations	330
#
# 7.13.3.1.2.4	Type: RCSDestination	330
#
# 7.13.3.2	Registration	330
#
# 7.13.3.2.1	 RCS registration record	330
#
# 7.13.3.2.2	RCS Registration parameters	331
#
# 7.13.3.2.2.1	Enumeration: RCSRegistrationType	331
#
# 7.13.3.3	RCS Message	331
#
# 7.13.3.3.1	RCS Message record	331
#
# 7.13.3.3.2	RCS Message parameters	333
#
# 7.13.3.3.2.1	Type: RCSMessageType	333
#
# 7.13.3.3.2.2	Type: RCSPayload	333
#
# 7.13.3.3.2.3	Type: EncapsulatedRCSPayload	333
#
# 7.13.3.4	Session establishment	333
#
# 7.13.3.5	Capability discovery	333
#
# 7.13.3.5.1	 RCS Capability discovery record	333
#
# 7.14	LI at EES	334
#
# 7.14.1	Provisioning over LI_X1	334
#
# 7.14.1.1	Provisioning of IRI-POI in EES	334
#
# 7.14.1.2	Provisioning of the MDF2	335
#
# 7.14.2	Generation of xIRI at IRI-POI in EES over LI_X2	336
#
# 7.14.2.1	General	336
#
# 7.14.2.2	EEC registration and deregistration	336
#
# 7.14.2.3	EAS discovery	337
#
# 7.14.2.4	EAS discovery subscription	338
#
# 7.14.2.5	EAS discovery notification	339
#
# 7.14.2.6	Application context relocation	339
#
# 7.14.2.7	Application context relocation information subscription	340
#
# 7.14.2.8	Application context relocation information notification	341
#
# 7.14.2.9	EEC context relocation	341
#
# 7.14.2.10	Start of interception with registered EEC	342
#
# 7.14.2.11	Generation of IRI over LI_HI2	342
#
# 7.15	LI at 5GMS AF	343
#
# 7.15.1	Provisioning over LI_X1	343
#
# 7.15.1.1	Provisioning of IRI-POI in 5GMS AF	343
#
# 7.15.1.2	Provisioning of the MDF2	343
#
# 7.15.2	Generation of xIRI over LI_X2	344
#
# 7.15.2.1	General	344
#
# 7.15.2.2	Service access information	344
#
# 7.15.2.3	Consumption reporting	344
#
# 7.15.2.4	Dynamic policy invocation	345
#
# 7.15.2.5	Metrics reporting	345
#
# 7.15.2.6	Network assistance	346
#
# 7.15.2.7	Unsuccessful procedure	346
#
# 7.15.2.8	Start of interception with already configured UE	347
#
# 7.15.3	Generation of IRI over LI_HI2	348
#
# Annex A (normative): ASN.1 Schema for the Internal and External Interfaces	349
#
# Annex B (normative): LI Notification	349
#
# Annex C (normative): XSD Schema for LI_X1 extensions	350
#
# Annex D (informative): Drafting Guidance	350
#
# D.1	Introduction	350
#
# D.2	Drafting conventions	351
#
# D.3	Naming conventions	351
#
# D.4	ASN.1 Syntax conventions	352
#
# Annex E (normative): XSD Schema for Identity Association	353
#
# Annex F (normative): ASN.1 Schema for LI_XER messages	353
#
# Annex G: Void		353
#
# Annex H (normative): XSD Schema for State Transfers	353
#
# Annex I (normative): XSD Schema for Location Acquisition	353
#
# Annex L (normative): XSD Schema for LI Queries	353
#
# Annex M (normative): Reuse of externally defined structures	354
#
# M.1	Encapsulated Information	354
#
# M.1.1	General	354
#
# M.1.2	Encapsulated information reporting parameters	354
#
# M.1.2.1	Simple Types for encapsulate information reporting	354
#
# M.1.2.2	Type: SBIType	355
#
# M.1.2.3	Type: XMLType	355
#
# M.1.2.4	Type: MIMEEntity	355
#
# M.1.2.5	Type: MSRPMessage	355
#
# M.1.2.6	Type: MIMEPartIdentifier	355
#
# Annex Z (informative): Change history	356
#
#
#
# Foreword
#
# This Technical Specification has been produced by the 3rd Generation Partnership Project (3GPP).
#
# The contents of the present document are subject to continuing work within the TSG and may change following formal TSG approval. Should the TSG modify the contents of the present document, it will be re-released by the TSG with an identifying change of release date and an increase in version number as follows:
#
# Version x.y.z
#
# where:
#
# x	the first digit:
#
# 1	presented to TSG for information;
#
# 2	presented to TSG for approval;
#
# 3	or greater indicates TSG approved document under change control.
#
# y	the second digit is incremented for all changes of substance, i.e. technical enhancements, corrections, updates, etc.
#
# z	the third digit is incremented when editorial only changes have been incorporated in the document.
#
# Introduction
#
# The present document has been produced by the 3GPP TSG SA to standardise Lawful Interception of telecommunications. The present document describes protocols and procedures for Lawful Interception based on 3GPP specifications. These protocols and procedures cover both internal 3GPP interfaces (those required to intercept communications and manage interception within a 3GPP network) and external handover interfaces (those used for delivery of intercepted communications to Law Enforcement, or handling of warrants).
#
# Lawful Interception needs to be done in accordance with the applicable national or regional laws and technical regulations. Such national laws and regulations define the extent to which capabilities in the present document are applicable in specific jurisdictions.
#
# 1	Scope
#
# The present document specifies the protocols and procedures required to perform Lawful Interception within a 3GPP network. The present document addresses both internal interfaces used internally with a 3GPP network and external handover interfaces used to handover intercepted communications to law enforcement.
#
# The present document describes the detailed targeting of communications in each point of interception within a 3GPP network and the information that a point of interception needs to be able to capture. Furthermore, the detailed data formats for both the internal and external interfaces are also defined.
#
# National regulations determine the applicable set of information that needs to be handed over or excluded from handover to law enforcement for a given 3GPP operator service.
#
#
#
# 2	References
#
# The following documents contain provisions which, through reference in this text, constitute provisions of the present document.
#
# -	References are either specific (identified by date of publication, edition number, version number, etc.) or non-specific.
#
# -	For a specific reference, subsequent revisions do not apply.
#
# -	For a non-specific reference, the latest version applies. In the case of a reference to a 3GPP document (including a GSM document), a non-specific reference implicitly refers to the latest version of that document in the same Release as the present document.
#
# [1]	3GPP TR 21.905: "Vocabulary for 3GPP Specifications".
#
# [2]	3GPP TS 23.501: "System Architecture for the 5G System".
#
# [3]	3GPP TS 33.126: "Lawful Interception Requirements".
#
# [4]	3GPP TS 23.502: "Procedures for the 5G System; Stage 2".
#
# [5]	3GPP TS 33.127: "Lawful Interception (LI) Architecture and Functions".
#
# [6]	ETSI TS 103 120: "Lawful Interception (LI); Interface for warrant information".
#
# [7]	ETSI TS 103 221-1: "Lawful Interception (LI); Internal Network Interfaces; Part 1: X1".
#
# [8]	ETSI TS 103 221-2: "Lawful Interception (LI); Internal Network Interfaces; Part 2: X2/X3".
#
#  [9]	ETSI TS 102 232-1: "Lawful Interception (LI); Handover Interface and Service-Specific Details (SSD) for IP delivery; Part 1: Handover specification for IP delivery".
#
# [10]	ETSI TS 102 232-7: "Lawful Interception (LI); Handover Interface and Service-Specific Details (SSD) for IP delivery; Part 7: Service-specific details for Mobile Services".
#
# [11]	3GPP TS 33.501: "Security Architecture and Procedures for the 5G System".
#
# [12]	3GPP TS 33.108: "3G security; Handover interface for Lawful Interception (LI)".
#
# [13]	3GPP TS 24.501: "Non-Access-Stratum (NAS) protocol for 5G System (5GS)".
#
# [14]	3GPP TS 24.007: "Mobile radio interface signalling layer 3; General Aspects".
#
# [15]	3GPP TS 29.244: "Interface between the Control Plane and the User Plane nodes".
#
# [16]	3GPP TS 29.502: "5G System; Session Management Services; Stage 3".
#
# [17]	3GPP TS 29.571: "5G System; Common Data Types for Service Based Interfaces; Stage 3".
#
# [18]	3GPP TS 23.040: "Technical realization of the Short Message Service (SMS)".
#
# [19]	3GPP TS 23.003: "Numbering, addressing and identification ".
#
# [20]	OMA-TS-MLP-V3_5-20181211-C: "Open Mobile Alliance; Mobile Location Protocol, Candidate Version 3.5", https://www.openmobilealliance.org/release/MLS/V1_4-20181211-C/OMA-TS-MLP-V3_5-20181211-C.pdf.
#
# [21]	3GPP TS 29.540: "5G System; SMS Services; Stage 3".
#
# [22]	3GPP TS 29.518: "5G System; Access and Mobility Management Services; Stage 3".
#
# [23]	3GPP TS 38.413: "NG Application Protocol (NGAP)".
#
# [24]	3GPP TS 29.572: "Location Management Services; Stage 3".
#
# [25]	3GPP TS 29.503: "5G System; Unified Data Management Services".
#
# [26]	IETF RFC 815: "IP datagram reassembly algorithms".
#
# [27]	IETF RFC 2460: "Internet Protocol, Version 6 (IPv6) Specification".
#
# [28]	IETF RFC 793: "Transmission Control Protocol".
#
# [29]	IETF RFC 768: "User Datagram Protocol".
#
# [30]	IETF RFC 4340: "Datagram Congestion Control Protocol (DCCP)".
#
# [31]	IETF RFC 4960: "Stream Control Transmission Protocol".
#
# [32]	IANA (www.iana.org): Assigned Internet Protocol Numbers, "Protocol Numbers".
#
# [33]	IETF RFC 6437: "IPv6 Flow Label Specification".
#
# [34]	IETF RFC 791: "Internet Protocol".
#
# [35]	Open Geospatial Consortium OGC 05-010: "URNs of definitions in ogc namespace".
#
# [36]	3GPP TS 33.107: "3G security; Lawful interception architecture and functions".
#
# [37]	3GPP TS 37.340: "Evolved Universal Radio Access (E-UTRA) and NR-Multi-connectivity; Stage 2".
#
# [38]	3GPP TS 36.413: "S1 Application Protocol (S1AP)".
#
# [39]	OMA-TS-MMS_ENC-V1_3-20110913-A: "Multimedia Messaging Service Encapsulation Protocol".
#
# [40]	3GPP TS 23.140: "Multimedia Messaging Protocol. Functional Description. Stage 2".
#
# [41]	3GPP TS 38.415: "NG-RAN; PDU Session User Plane Protocol".
#
# [42]	3GPP TS 23.273: "5G System (5GS) Location Services (LCS); Stage 2".
#
# [43]	IETF RFC 4566: "SDP: Session Description Protocol".
#
# [44]	3GPP TS 24.193: "Stage 3: Access Traffic Steering, Switching and Splitting (ATSSS)".
#
# [45]	3GPP TS 29.509: "5G System; Authentication Server Services; Stage 3".
#
# [46]	3GPP TS 24.011: "Point-to-Point (PP) Short Message Service (SMS) support on mobile radio interface".
#
# [47]	3GPP TS 29.002: "Mobile Application Part (MAP) specification".
#
# [48]	3GPP TS 29.504: "5G System; Unified Data Repository Services; Stage 3".
#
# [49]	3GPP TS 29.505: "5G System; Usage of the Unified Data Repository services for Subscription Data; Stage 3".
#
# [50]	3GPP TS 23.401 "General Packet Radio Service (GPRS) enhancements for Evolved Universal Terrestrial Radio Access Network (E-UTRAN) access".
#
# [51]	3GPP TS 24.301 "Non-Access-Stratum (NAS) protocol for Evolved Packet System (EPS), Stage 3".
#
# [52]	3GPP TS 23.271 "Functional stage 2 description of Location Services (LCS)".
#
# [53]	3GPP TS 29.172 "Evolved Packet Core (EPC) LCS Protocol (ELP) between the Gateway Mobile Location Centre (GMLC) and the Mobile Management Entity (MME); SLg interface".
#
# [54]	3GPP TS 29.171 "LCS Application Protocol (LCS-AP) between the Mobile Management Entity (MME) and Evolved Serving Mobile Location Centre (E-SMLC); SLs interface".
#
# [55]	3GPP TS 24.379: "Mission Critical Push to Talk (MCPTT) call control; protocol specification".
#
# [56]	OMA-TS-PoC-System_Description-V2_1-20110802-A: "OMA PoC System Description".
#
# [57]	3GPP TS 29.541: "5G System; Network Exposure (NE) function services for Non-IP Data Delivery (NIDD); Stage 3".
#
# [58]	3GPP TS 29.522: "5G System; Network Exposure Function Northbound APIs; Stage 3".
#
# [59]	3GPP TS 29.338: "Diameter based protocols to support Short Message Service (SMS) capable Mobile Management Entities (MMEs); Stage 3".
#
# [60]	3GPP TS 29.337: "Diameter-based T4 interface for communications with packet data networks and applications".
#
# [61]	3GPP TS 24.250: "Protocol for Reliable Data Service; Stage 3".
#
# [62]	3GPP TS 29.128: "Mobility Management Entity (MME) and Serving GPRS Support Node (SGSN) interfaces for interworking with packet data networks and applications".
#
# [63]	3GPP TS 29.122: "T8 reference point for Northbound APIs".
#
# [64]	3GPP TS 29.598: "5G System; Unstructured Data Storage Services; Stage3".
#
# [65]	3GPP TS 33.535: "Authentication and Key Management for Applications (AKMA) based on 3GPP credentials in the 5G System (5GS)".
#
# [66]	IETF RFC 5246: "The Transport Layer Security (TLS) Protocol Version 1.2".
#
# [67]	GSMA IR.88: "IR.88 LTE and EPC Roaming Guidelines".
#
# [68]	GSMA NG.114 "IMS Profile for Voice, Video and Messaging over 5GS".
#
# [69]	IETF RFC 8225: "PASSporT: Personal Assertion Token".
#
# [70]	IETF RFC 8224: "Authenticated Identity Management in the Session Initiation Protocol (SIP)".
#
# [71]	IETF RFC 8588: "Personal Assertion Token (PaSSporT) Extension for Signature-based Handling of Asserted information using toKENs (SHAKEN)".
#
# [72]	3GPP TS 24.196: "Enhanced Calling Name (eCNAM)".
#
# [73]	IETF draft-ietf-stir-passport-rcd-17: "PASSporT Extension for Rich Call Data".
#
# NOTE:	The above document cannot be formally referenced until it is published as an RFC.
#
# [74]	3GPP TS 24.229: "IP multimedia call control protocol based on Session Initiation Protocol (SIP)and Session Description Protocol (SDP); Stage 3".
#
# [75]	IANA Session Initiation Protocol (SIP) Parameters: https://www.iana.org/assignments/sip-parameters/sip-parameters.xhtml
#
# [76]	IETF RFC 8946: "Personal Assertion Token (PASSporT) Extension for Diverted Calls".
#
# [77]	3GPP TS 23.204: "3rd Generation Partnership Project; Technical Specification Group Services and System Aspects; Support of Short Message Service (SMS) over generic 3GPP Internet Protocol (IP) access; Stage 2".
#
# [78]	GSMA RCC.07: "Rich Communication Suite – Advanced Communications Services and Client Specification".
#
# [79]	IETF RFC 4975: "The Message Session Relay Protocol (MSRP)".
#
# [80]	IETF RFC 3862: "Common Presence and Instant Messaging (CPIM): Message Format".
#
# [81]	IETF RFC 5438: "Instant Message Disposition Notification (IMDN)".
#
# [82]	OMA-TS-CPM_System_Description-V2_2-20170926-C: "OMA Converged IP Messaging System Description".
#
# [83]	Void.
#
# [84]	3GPP TS 36.455: "Evolved Universal Terrestrial Radio Access (E-UTRA); LTE Positioning Protocol A (LPPa) ".
#
# [85]	3GPP TS 37.355: "LTE Positioning Protocol (LPP)".
#
# [86]	3GPP TS 38.455: "NG-RAN; NR Positioning Protocol A (NRPPa)".
#
# [87]	3GPP TS 29.274: "3GPP Evolved Packet System (EPS); Evolved General Packet Radio Service (GPRS) Tunnelling Protocol for Control plane (GTPv2-C); Stage 3".
#
# [88]	3GPP TS 29.513: "5G System; Policy and Charging Control signalling flows and QoS parameter mapping".
#
# [89]	3GPP TS 29.512: "5G System; Session Management Policy Control Service; Stage 3".
#
# [90]	3GPP TS 29.508: "5G System; Session Management Event Exposure Service; Stage 3".
#
# [91]	3GPP TS 29.514: "5G System; Policy Authorization Service; Stage 3".
#
# [92]	3GPP TS 29.214: "Policy and Charging Control over Rx reference point".
#
# [93]	3GPP TS 24.558: "Enabling Edge Applications; Protocol specification".
#
# [94]	3GPP TS 29.558: "Enabling Edge Applications; Application Programming Interface (API) specification".
#
# [95]	3GPP TS 24.008: "Mobile radio interface Layer 3 specification; Core network protocols; Stage 3".
#
# [96]	3GPP TS 29.551: "5G System; Packet Flow Description Management Service; Stage 3".
#
# [97]	ETSI TS 103 280: "Lawful Interception (LI); Dictionary for common parameters".
#
# [98]	3GPP TS 26.512: "5G Media Streaming (5GMS); Protocols".
#
# [99]	3GPP TS 26.247: "Transparent end-to-end Packet-switched Streaming Service (PSS); Progressive Download and Dynamic Adaptive Streaming over HTTP (3GP-DASH)".
#
# [100]	3GPP TS 29.563: "5G System; Home Subscriber Server (HSS) services for interworking with Unified Data Management (UDM); Stage 3".
#
# [101]	3GPP TS 29.562: "5G System; Home Subscriber Server (HSS) Services; Stage 3".
#
# [102]	3GPP TS 24.341 "Support of SMS over IP networks, Stage 3".
#
# [103]	3GPP TS 38.473 "NG-RAN;F1 application protocol (F1AP)".
#
# [104]	3GPP TS 23.032: "Universal Geographical Area Description (GAD)".
#
# [105]	ITU-T Recommendation Q.763 (1999): "Specifications of Signalling System No.7; Formats and codes".
#
# [106]	3GPP TS 29.272: "Mobility Management Entity (MME) and Serving GPRS Support Node (SGSN) related interfaces based on Diameter protocol".
#
# [107]	IETF RFC 6442: "Location Conveyance for the Session Initiation Protocol".
#
# [108]	Void.
#
# [109]	OMA-TS-CPM_Conv_Function: "OMA CPM Conversation Functions".
#
# [110]	IETF RFC 2045: "Multipurpose Internet Mail Extensions (MIME) Part One: Format of Internet Message Bodies".
#
# [111]	3GPP TS 32.299: " Telecommunication management; Charging management; Diameter charging applications".
#
# [112]	3GPP TS 32.423: "Telecommunication management; Subscriber and equipment trace; Trace data definition and management".
#
# [113]	3GPP TS 38.414: "NG-RAN; NG data transport".
#
# [114]	IETF RFC 2045: "Multipurpose Internet Mail Extensions (MIME) Part One: Format of Internet Message Bodies".
#
# [115]	IETF RFC 5322: "Internet Message Format".
#
# [116]	IETF RFC 4975: "The Message Session Relay Protocol (MSRP)".
#
# [117]	IETF RFC 6901: "JavaScript Object Notation (JSON) Pointer".
#
# [118]	IETF RFC 3261: "SIP: Session Initiation Protocol".
#
# [119]	W3C Recommendation: "XML Path Language (XPath)".
#
# [120]	IETF RFC 2046: "Multipurpose Internet Mail Extensions (MIME) Part Two: Media Types".
#
# [121]	3GPP TR 33.928: "ADMF Logic for Provisioning Lawful Interception (LI) ".
#
# 3	Definitions, symbols and abbreviations
#
# 3.1	Definitions
#
# For the purposes of the present document, the terms and definitions given in 3GPP TR 21.905 [1] and the following apply. A term defined in the present document takes precedence over the definition of the same term, if any, in 3GPP TR 21.905 [1].
#
#
#
# 3.2	Symbols
#
# For the purposes of the present document, the following symbols apply:
#
# <symbol>	<Explanation>
#
#
#
# 3.3	Abbreviations
#
# For the purposes of the present document, the abbreviations given in 3GPP TR 21.905 [1] and the following apply. An abbreviation defined in the present document takes precedence over the definition of the same abbreviation, if any, in 3GPP TR 21.905 [1].
#
#
#
# ADMF	LI Administration Function
#
# CC	Content of Communication
#
# CSP	Communication Service Provider
#
# CUPS	Control and User Plane Separation
#
# DNAI	Data Network Access Identifier
#
# ICF	Identity Caching Function
#
# IEF	Identity Event Function
#
# IQF	Identity Query Function
#
# IRI	Intercept Related Information
#
# LAF	Location Acquisition Function
#
# LALS 	Lawful Access Location Services
#
# LARF	Location Acquisition Requesting Function
#
# LEA	Law Enforcement Agency
#
# LEMF	Law Enforcement Monitoring Facility
#
# LI	Lawful Interception
#
# LICF	Lawful Interception Control Function
#
# LI_HI1	LI_Handover Interface 1
#
# LI_HI2	LI_Handover Interface 2
#
# LI_HI3	LI_Handover Interface 3
#
# LI_HI4	LI_Handover Interface 4
#
# LI_HILA	Lawful Interception Handover Interface Location Acquisition
#
# LI_HIQR	Lawful Interception Handover Interface Query Response
#
# LIPF	Lawful Interception Provisioning Function
#
# LIR	Location Immediate Request
#
# LI_SI	Lawful Interception System Information Interface
#
# LISSF	Lawful Interception State Storage Function
#
# LI_ST	Lawful Interception State Transfer Interface
#
# LI_X1	Lawful Interception Internal Interface 1
#
# LI_X2	Lawful Interception Internal Interface 2
#
# LI_X2_LA	Lawful Interception Internal Interface 2 Location Acquisition
#
# LI_X3	Lawful Interception Internal Interface 3
#
# LI_XEM1	Lawful Interception Internal Interface Event Management Interface 1
#
# LI_XER	Lawful Interception Internal Interface Event Record
#
# ...
#
# Table 7.15.2.3-1: Payload for FiveGMSAFConsumptionReporting
#
#
#
# 7.15.2.4	Dynamic policy invocation
#
# The IRI-POI in the 5GMS AF shall generate an xIRI containing an 5GMSAFDynamicPolicyInvocation record when the IRI-POI present in the 5GMS AF detects that an 5GMS AF has received a dynamic policy from the target UE. The IRI-POI present in the 5GMS AF shall generate the xIRI for the following events (as specified in TS 26.512 [98], clause 11.5):
#
# -	5GMS AF returns a createDynamicPolicy Response (i.e. 201 Created) in response to a createDynamicPolicy Request (i.e. POST) from the Media Session Handler in the target UE which creates a dynamic policy resource.
#
# -	5GMS AF returns a retrieveDynamicPolicy Response (i.e. 20O OK) in response to a retrieveDynamicPolicy Request (i.e. GET) from the Media Session Handler in the target UE which retrieves the dynamic policy resource.
#
# -	5GMS AF returns an updateDynamicPolicy Response (i.e. 20O OK or 204 No Content) in response to an updateDynamicPolicy Request (i.e. PUT) from the Media Session Handler in the target UE which replaces the dynamic policy resource.
#
# -	5GMS AF returns a patchDynamicPolicy Response (i.e. 20O OK or 204 No Content) in response to a patchDynamicPolicy Request (i.e. PATCH) from the Media Session Handler in the target UE which modifies the dynamic policy resource.
#
# -	5GMS AF returns a destroyDynamicPolicy Response (i.e. 204 No Content) in response to a destroyDynamicPolicy Request (i.e. DELETE) from the Media Session Handler of the target UE which deletes the dynamic policy resource.
#
# Table 7.15.2.4-1: Payload for FiveGMSAFDynamicPolicyInvocation
#
#
#
# 7.15.2.5	Metrics reporting
#
# The IRI-POI in the 5GMS AF shall generate an xIRI containing an 5GMSAFMetricsReporting record when the IRI-POI present in the 5GMS AF detects that an 5GMS AF has received a metrics report from the target UE. The IRI-POI present in the 5GMS AF shall generate the xIRI for the following event (as specified in TS 26.512 [98], clause 11.4):
#
# -	5GMS AF returns submitMetricsReport Response (i.e. 204 No Content) in response to a submitMetricsReport Request (i.e. POST) from the Media Session Handler in the target UE which submits a metrics report.
#
# Table 7.15.2.5-1: Payload for FiveGMSAFMetricsReporting
#
#
#
# 7.15.2.6	Network assistance
#
# The IRI-POI in the 5GMS AF shall generate an xIRI containing an FiveGMSAFNetworkAssistance record when the IRI-POI present in the 5GMS AF detects that an 5GMS AF has received a network assistance from the target UE. The IRI-POI present in the 5GMS AF shall generate the xIRI for the following events (as specified in TS 26.512 [98], clause 11.6):
#
# -	5GMS AF returns a createNetworkAssistanceSession Response (i.e. 201 Created) in response to a createNetworkAssistanceSession Request (i.e. POST) from the Media Session Handler in the target UE which creates a network assistance session resource.
#
# -	5GMS AF returns a retrieveNetworkAssistanceSession Response (i.e. 200 OK) in response to a retrieveNetworkAssistanceSession Request (i.e. GET) from the Media Session Handler in the target UE which retrieves an existing network assistance session resource.
#
# -	5GMS AF returns an updateNetworkAssistanceSession Response (i.e. 200 OK or 204 No Content) in response to an updateNetworkAssistanceSession Request (i.e. PUT) from the Media Session Handler in the target UE which replaces an existing network assistance session resource.
#
# -	5GMS AF returns a patchNetworkAssistanceSession Response (i.e. 200 OK or 204 No Content) in response to a patchNetworkAssistanceSession Request (i.e. PATCH) from the Media Session Handler in the target UE which modifies the network assistance session resource.
#
# -	5GMS AF returns a destroyNetworkAssistanceSession Response (i.e. 204 No Content) in response to a destroyNetworkAssistanceSession Request (i.e. DELETE) from the Media Session Handler in the target UE which deletes the network assistance session resource.
#
# -	5GMS AF returns a requestBitRateRecommendation Response (i.e. 200 OK) in response to a requestBitRateRecommendation Request (i.e. GET) from the Media Session Handler in the target UE which requests a bit rate recommendation for the next recommendation window.
#
# -	5GMS AF returns a requestDeliveryBoost Response (i.e. 200 OK) in response to a requestDeliveryBoost Request (i.e. POST) from the Media Session Handler in the target UE which requests a delivery boost.
#
# Table 7.15.2.6-1: Payload for FiveGMSAFNetworkAssistance
#
#
#
# 7.15.2.7	Unsuccessful procedure
#
# The IRI-POI in the 5GMS AF shall generate an xIRI containing a FiveGMSAFUnsuccessfulProcedure record when the IRI-POI present in the 5GMS AF detects an unsuccessful procedure or error condition for a target UE. Accordingly, the IRI-POI in the 5GMS AF generates the xIRI when any of the following events are detected:
#
# -	5GMS AF returns retrieveServiceAccessInformation response (i.e. 404 Not Found) in response to retrieveServiceAccessInformation request (i.e. GET) from the target UE.
#
# -	5GMS AF returns submitConsumptionReport Response (i.e. 400 Bad Request or 415 Unsupported Media Type) in response to a submitConsumptionReport Request (i.e. POST) from the target UE.
#
# -	5GMS AF returns submitMetricsReport Response (i.e. 400 Bad Request or 415 Unsupported Media Type) in response to a submitMetricsReport Request (i.e. POST) from the target UE.
#
# -	5GMS AF returns a createDynamicPolicy Response (i.e. 400 Bad Request or 401 Unauthorized) in response to a createDynamicPolicy Request (i.e. POST) from the target UE.
#
# -	5GMS AF returns a retrieveDynamicPolicy Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a retrieveDynamicPolicy Request (i.e. GET) from the target UE.
#
# -	5GMS AF returns an updateDynamicPolicy Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to an updateDynamicPolicy Request (i.e. PUT) from the target UE.
#
# -	5GMS AF returns a patchDynamicPolicy Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a patchDynamicPolicy Request (i.e. PATCH) from the target UE.
#
# -	5GMS AF returns a destroyDynamicPolicy Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a destroyDynamicPolicy Request (i.e. DELETE) from the target UE.
#
# -	5GMS AF returns a createNetworkAssistanceSession Response (i.e. 400 Bad Request or 401 Unauthorized) in response to a createNetworkAssistanceSession Request (i.e. POST) from the target UE.
#
# -	5GMS AF returns a retrieveNetworkAssistanceSession Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a retrieveNetworkAssistanceSession Request (i.e. GET) from the target UE.
#
# -	5GMS AF returns an updateNetworkAssistanceSession Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to an updateNetworkAssistanceSession Request (i.e. PUT) from the target UE.
#
# -	5GMS AF returns a patchNetworkAssistanceSession Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a patchNetworkAssistanceSession Request (i.e. PATCH) from the target UE.
#
# -	5GMS AF returns a destroyNetworkAssistanceSession Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a destroyNetworkAssistanceSession Request (i.e. DELETE) from the target UE.
#
# -	5GMS AF returns a requestBitRateRecommendation Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a requestBitRateRecommendation Request (i.e. GET) from the target UE.
#
# -	5GMS AF returns a requestDeliveryBoost Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a requestDeliveryBoost Request (i.e. POST) from the target UE.
#
# Table 7.15.2.7-1: Payload for FiveGMSAFNetworkAssistance
#
#
#
# 7.15.2.8	Start of interception with already configured UE
#
# The IRI-POI in the 5GMS AF shall generate an xIRI containing an FiveGMSAFStartOfInterceptionWithAlreadyConfiguredUE record when the IRI-POI present in the 5GMS AF detects that interception is activated for a target UE which Media Session Handler has already been configured with the service access information.
#
# Table 7.15.2.8-1: Payload for FiveGMSAFStartOfInterceptionWithAlreadyConfiguredUE
#
#
#
# 7.15.3	Generation of IRI over LI_HI2
#
# When an xIRI is received over LI_X2 from the IRI-POI in the 5GMS AF, the MDF2 shall send the IRI message over LI_HI2 without undue delay. The IRI message shall contain a copy of the relevant record received from LI_X2. The record may be enriched by other information available at the MDF (e.g. additional location information).
#
# The timestamp field of the ETSI TS 102 232-1 [9] PSHeader structure shall be set to the time at which the 5GMS AF event was observed (i.e. the timestamp field of the xIRI).
#
# The IRI type parameter shall be included and coded according to table 7.14.2-19 (see ETSI TS 102 232-1 [9] clause 5.2.10).
#
# Table 7.15.3-1: IRI type for IRI messages
#
#
#
# The threeGPP33128DefinedIRI field (see ETSI TS 102 232-7 [10] clause 15) shall be populated with the BER-encoded IRIPayload.
#
# MDF2 delivers the IRI to the LEMF with GPSI as the target identity if and only if GPSI is present in the xIRI.
#
#
#
# Annex A (normative):
# ASN.1 Schema for the Internal and External Interfaces
#
# The ASN.1 module describing the structures used for LI_X2, LI_X3, LI_HI2 and LI_HI3 ("TS33128Payloads") is given in the file TS33128Payloads.asn which accompanies the present document.
#
# Annex B (normative):
# LI Notification
#
# Based on clause 5.6 of the present document, this annex defines a system of management notification of LI system with the LI_HI4 interface.
#
# The LI_HI4 interface shall be used to transport specific LI service O&M information (referred to as LI Notification) from the CSP to the LEMF. The individual parameters of the LI Notification message shall be coded using ASN.1 and the basic encoding rules (BER). The delivery of LI Notification shall be performed directly using the same mechanism as used for delivery of IRI messages over LI_HI2 and CC over LI_HI3.
#
# The LI Notification shall be used to send electronic notification to the LEMF in the following cases:
#
# 1)	after the activation of lawful interception;
#
# 2)	after the deactivation of lawful interception;
#
# 3)	after the modification of an active lawful interception.
#
# Table B.1-1: LINotification message
#
#
#
# Conditional parameters shall be set as follows:
#
#
#
#
#
#
#
# The individual notifications parameters shall be sent to the LEMF as soon as possible with the lowest latency at least once (if available).
#
# The MDF2/3 will deliver the LINotification message to LEMF.
#
# Annex C (normative):
# XSD Schema for LI_X1 extensions
#
# The XSD schema describing the extensions used for LI_X1 is given in the file urn_3GPP_ns_li_3GPPX1Extensions.xsd which accompanies the present document.
#
# Annex D (informative):
# Drafting Guidance
#
# D.1	Introduction
#
# This annex provides drafting guidance for contributors wishing to propose changes to the present document.
#
# D.2	Drafting conventions
#
# Table D.2-1: Drafting conventions
#
#
#
# D.3	Naming conventions
#
# Table D.3-1: Naming conventions
#
#
#
# ExampleBadStructure ::= SEQUENCE
#
# {
#
# 	FirstField		[1] FirstFieldType,		-- D.3.1 First letter of field is upper case
#
# 	secondField		[2] secondFieldType,	-- D.3.2 First letter of type is lower case
#
# 	3rdField		[3] 3rdFieldType,		-- D.3.3 Names starts with digit
#
# 	fourth-field	[4]	Fourth_Field_Type,	-- D.3.4 Names include hyphen and underscore
#
# 	fifthfield		[5]	Fifthfieldtype,		-- D.3.5 Names are not camelCased
#
# 	msisdn			[6] MSISDN,				-- D.3.6 Acronyms in field name not wholly upper-cased
#
# 	mSISDN			[7] Msisdn				-- D.3.6 Acronyms in type name not wholly upper-cased
#
# }
#
# Figure 1 – Naming convention counter-examples
#
#
#
# D.4	ASN.1 Syntax conventions
#
# Table D.4-1: ASN.1 Syntax conventions
#
#
#
# ConformantModule
#
# {itu-t(0) identified-organization(4) etsi(0) securityDomain(2) lawfulIntercept(2) ... }
#
#
#
# DEFINITIONS EXTENSIBILITY IMPLIED ::=
#
#
#
# BEGIN
#
#
#
#
#
# Structure1 ::= SEQUENCE
#
# {
#
#     field1	[1] Field1,
#
#     field2	[2] Field2
#
# }
#
#
#
# Field1 ::= ENUMERATED
#
# {
#
#     choice1(1),
#
#     choice2(2),
#
#     choice3(3)
#
# }
#
#
#
# Field2 ::= OCTET STRING
#
#
#
# END
#
# Figure 2 – Syntax convention example
#
# NonconformantModule
#
# {itu-t(0) identified-organization(4) etsi(0) securityDomain(2) lawfulIntercept(2) ... }
#
#
#
# DEFINITIONS AUTOMATIC TAGS ::=          -- D.4.1 Not declared with EXTENSIBILITY IMPLIED
#
#                                         -- D.4.2 Declared AUTOMATIC TAGS
#
# BEGIN
#
#
#
# Structure1 ::= SEQUENCE {               -- D.4.11 Braces not given their own line
#
#     field1  [0] ::= ENUMERATED          -- D.4.3 SEQUENCE tags don’t start at 1
#
#     {                                   -- D.4.5 Anonymous type used
#
#         choice1(0),                     -- D.4.4 ENUMERATED tag numbers don’t start at 1
#
#         choice2(2),
#
#         choice3(3)
#
#     },
#
#     field2  [2] Field2                  -- D.4.10 Field name is bold
#
# }
#
#
#
# Field2 ::= OCTET STRING                 -- D.4.10 Type names in definitions is bold
#
#
#
# END
#
# Figure 3 – Syntax convention counter-examples
#
# Annex E (normative):
# XSD Schema for Identity Association
#
# The XSD schema describing the extensions used for Identity Association is given in the file urn_3GPP_ns_li_3GPPIdentityExtensions.xsd which accompanies the present document.
#
# Annex F (normative):
# ASN.1 Schema for LI_XER messages
#
# The ASN.1 schema describing the structures used for LI_XER is given in the file TS33128IdentityAssociation.asn which accompanies the present document.
#
# Annex G:
# Void
#
# The ASN.1 schema describing the structures used for LI_XER is given in the file TS33128IdentityAssociation.asn which accompanies the present document.
#
# Annex H (normative):
# XSD Schema for State Transfers
#
# The XSD schema describing the structures used for state transfer is given in the file urn_3GPP_ns_li_3GPPStateTransfer.xsd which accompanies the present document.
#
# Annex I (normative):
# XSD Schema for Location Acquisition
#
# The XSD schema describing the structures used for Location Acquisition query extensions is given in the file urn_3GPP_ns_li_3GPPXLAExtensions.xsd which accompanies the present document.
#
# Annex L (normative):
# XSD Schema for LI Queries
#
# The XSD schema describing the structures used for LI queries is given in the file  urn_3GPP_ns_li_3GPPLIQueryExtensions.xsd which accompanies the present document.
#
# Annex M (normative):
# Reuse of externally defined structures
#
# M.1	Encapsulated Information
#
# M.1.1	General
#
# The subclauses below define LI structures to allow for the reuse of externally defined structures and schemas.
#
# The current version of this specification the following specific encapsulated information types are defined:
#
# -	SBIType for carrying messages or parameters defined by 3GPP for use over the Service Based Interfaces (SBIs).
#
# -	XMLTypes for carrying messages or parameters in XML.
#
# -	MIMEEntity for carrying MIME Entities.
#
# -	MSRPMessage for sending information formated in an MSRP Message.
#
# The encapsulated information type of the outermost layer of the encapsulated payload shall be used to report the payload.
#
# M.1.2	Encapsulated information reporting parameters
#
# M.1.2.1	Simple Types for encapsulate information reporting
#
# Table M.1.2.1-1: Simple Types for LI reporting of encapsulated information
#
#
#
# M.1.2.2	Type: SBIType
#
# Table M.1.2.2-1: Structure of the SBIType type
#
#
#
# M.1.2.3	Type: XMLType
#
# Table M.1.2.3-1: Structure of the XMLType type
#
#
#
# M.1.2.4	Type: MIMEEntity
#
# Table M.1.2.4-1: Structure of the MIMEEntity type
#
#
#
# M.1.2.5	Type: MSRPMessage
#
# Table M.1.2.5-1: Structure of the MSRPMessage type
#
#
#
# M.1.2.6	Type: MIMEPartIdentifier
#
# Table M.1.2.6-1: Structure of the MIMEPartIdentifier type
#
#
#
#
#
# Annex Z (informative):
# Change history
#
#
#
#
#
# Extracted text saved to: /Users/aadivikram/Desktop/3GPP_extracted/output_p/extracted_text.txt

# %%
#Best chunk creation in .txt file

# %%
import re

# Read text from the input file
with open('/Users/aadivikram/Desktop/3GPP_extracted/output_p/extracted_text.txt', 'r') as file:
    text = file.read()

# Find the indices of the first occurrence of '3GPP TS' and 'Contents'
first_3gpp_ts = text.find('3GPP TS')
first_contents = text.find('Contents')

# Find the indices of the second occurrence of 'Foreword'
first_foreword = text.find('Foreword')
second_foreword = text.find('Foreword', first_foreword + 1)

# Find the index of the first occurrence of 'Introduction' after the second 'Foreword'
first_introduction = text.find('Introduction', second_foreword)

# Find the indices of the second occurrence of '1 Scope'
first_scope = text.find('1	Scope')
second_scope = text.find('1	Scope', first_scope + 1)

# Extract the first chunk between '3GPP TS' and 'Contents'
if first_3gpp_ts != -1 and first_contents != -1:
    first_chunk = text[first_3gpp_ts:first_contents]
    print("Chunk 1:")
    print(first_chunk.strip())
    print("=" * 50)

# Extract the second chunk between 'Contents' and the second 'Foreword'
if first_contents != -1 and second_foreword != -1:
    second_chunk = text[first_contents:second_foreword]
    print("\nChunk 2:")
    print(second_chunk.strip())
    print("=" * 50)

# Extract the third chunk between the second 'Foreword' and the first 'Introduction'
if second_foreword != -1 and first_introduction != -1:
    third_chunk = text[second_foreword:first_introduction]
    print("\nChunk 3:")
    print(third_chunk.strip())
    print("=" * 50)

# Extract the fourth chunk between 'Introduction' and the second '1 Scope'
if first_introduction != -1 and second_scope != -1:
    fourth_chunk = text[first_introduction:second_scope]
    print("\nChunk 4:")
    print(fourth_chunk.strip())
    print("=" * 50)

# Extract the remaining text based on the given regex pattern after Chunk 4
remaining_text = text[second_scope:]
sections = re.split(r'\n(?=\d+(\.\d+){0,2}\s)(?!\.\d)', remaining_text)

print("\nRemaining Text Sections:")
# Print non-empty and relevant sections
chunk_count = 4  # Initialize chunk count from the previous chunks
for i, section in enumerate(sections, start=1):
    if section and section.strip() and not re.match(r'^\.?\d+\s*$', section.strip()):
        chunk_count += 1  # Increment chunk count for each new section
        print(f"Chunk {chunk_count}:")
        print(section.strip())
        print("=" * 50)  # Separator for better visualization

# If there's no remaining text, don't print anything
if chunk_count == 4:
    print("No remaining text.")
# Out:
# Chunk 1:
# 3GPP TS 33.128 V18.4.0 (2023-06)
# Technical Specification
# 3rd Generation Partnership Project;
# Technical Specification Group Services and System Aspects;
# Security;
# Protocol and procedures for Lawful Interception (LI);
# Stage 3
# (Release 18)
#
#
#
#
#
#
# Keywords
# 5G, 4G, 3G, Security, LI, Protocol, Procedures
#
# 3GPP
# Postal address
#
# 3GPP support office address
# 650 Route des Lucioles - Sophia Antipolis
# Valbonne - FRANCE
# Tel.: +33 4 92 94 42 00 Fax: +33 4 93 65 47 16
# Internet
# https://www.3gpp.org
#
# Copyright Notification
# No part may be reproduced except as authorized by written permission.
# The copyright and the foregoing restriction extend to reproduction in all media.
#
# © 2023, 3GPP Organizational Partners (ARIB, ATIS, CCSA, ETSI, TSDSI, TTA, TTC).
#
# UMTS™ is a Trade Mark of ETSI registered for the benefit of its members
# 3GPP™ is a Trade Mark of ETSI registered for the benefit of its Members and of the 3GPP Organizational Partners
# LTE™ is a Trade Mark of ETSI registered for the benefit of its Members and of the 3GPP Organizational Partners
# GSM® and the GSM logo are registered and owned by the GSM Association
# ==================================================
#
# Chunk 2:
# Contents
# Foreword	17
# Introduction	17
# 1	Scope	18
# 2	References	18
# 3	Definitions, symbols and abbreviations	22
# 3.1	Definitions	22
# 3.2	Symbols	22
# 3.3	Abbreviations	23
# 4	General	24
# 4.1	Introduction	24
# 4.2	Basic principles for internal interfaces	25
# 4.3	Basic principles for external handover interfaces	26
# 4.4	Service scoping	27
# 4.4.1	General	27
# 4.4.2	CSP service type	27
# 4.4.3	Delivery type	27
# 4.4.4	Location Reporting	28
# 4.4.5	LALS Triggering	28
# 4.4.6	Roaming Interception	28
# 5	Transport and Communications Protocol	28
# 5.1	General	28
# 5.2	Protocols for LI_X1 and LI_T interfaces	28
# 5.2.1	General usage of ETSI TS 103 221-1	28
# 5.2.2	Usage for realising LI_X1	29
# 5.2.3	Usage for realising LI_X1 (management)	29
# 5.2.4	Service scoping	29
# 5.2.5	Usage for realising LI_T2	30
# 5.2.6	Usage for realising LI_T3	30
# 5.2.7	Usage for realising LI_XEM1	31
# 5.3	Protocols for LI_X2 and LI_X3	32
# 5.3.1	General usage of ETSI TS 103 221-2	32
# 5.3.2	Usage for realising LI_X2	32
# 5.3.3	Usage for realising LI_X3	32
# 5.3.4	Service scoping	33
# 5.3.5	Usage for realising LI_X2_LA	33
# 5.4	Protocols for LI_HI1	33
# 5.4.1	General	33
# 5.4.2	Service scoping	34
# 5.4.3	Location acquisition	34
# 5.5	Protocols for LI_HI2 and LI_HI3	34
# 5.5.1	General	34
# 5.5.2	Usage for realising LI_HI2	34
# 5.5.3	Usage for realising LI_HI3	35
# 5.5.4	Service scoping	35
# 5.5.5	IRI Target Identifiers	35
# 5.6	Protocols for LI_HI4	35
# 5.6.1	General	35
# 5.6.2	Usage for realising LI_HI4	36
# 5.7	Protocols for LI_HIQR	36
# 5.7.1	General	36
# 5.7.2	Usage for realising LI_HIQR	36
# 5.7.2.1	Request structure	36
# 5.7.2.2	Request parameters	37
# 5.7.2.3	Response structure	38
# 5.8	Protocols for LI_XQR	39
# 5.8.1	General	39
# 5.8.2	Identity association requests	40
# 5.8.3	Ongoing identity association requests	40
# 5.9	Protocols for LI_XER	40
# 5.10	Protocols for LI_ST interface	41
# 5.10.1	Overview	41
# 5.10.2	Storage	41
# 5.10.3	Retrieval	41
# 5.10.4	Removal	41
# 5.11	Protocols for LI_HILA	41
# 5.11.1	General	41
# 5.11.2	Usage for realising LI_HILA	42
# 5.11.2.1	Request structure	42
# 5.11.2.2	Request parameters	42
# 5.11.2.3	Response structure	43
# 5.12	Protocols for LI_XLA	43
# 5.12.1	General	43
# 5.12.2	Usage for realising LI_XLA	44
# 6	Network Layer Based Interception	44
# 6.1	Introduction	44
# 6.2	5G	45
# 6.2.1	General	45
# 6.2.2	LI at AMF	45
# 6.2.2.1	Provisioning over LI_X1	45
# 6.2.2.2	Generation of xIRI over LI_X2	46
# 6.2.2.2.1	General	46
# 6.2.2.2.2	Registration	46
# 6.2.2.2.3	Deregistration	47
# 6.2.2.2.4	Location update	48
# 6.2.2.2.5	Start of interception with registered UE	49
# 6.2.2.2.6	AMF unsuccessful procedure	50
# 6.2.2.2.7	AMF identifier association	51
# 6.2.2.2.8	Positioning info transfer	51
# 6.2.2.2.9	Handovers	52
# 6.2.2.2.10	UE Configuration Update	54
# 6.2.2.2.11	Trace	54
# 6.2.2.2.11.1	General	54
# 6.2.2.2.11.2	AMF RAN trace report	54
# 6.2.2.3	Generation of IRI over LI_HI2	55
# 6.2.2.4	Identity privacy	56
# 6.2.2A	Identifier Reporting for AMF	56
# 6.2.2A.1	Activation of reporting over LI_XEM1	56
# 6.2.2A.2	Generation of records over LI_XER	56
# 6.2.2A.2.2	Association Events	57
# 6.2.2A.2.3	Transmission to the ICF	58
# 6.2.3	LI for SMF/UPF	58
# 6.2.3.1	Provisioning over LI_X1	58
# 6.2.3.1.1	General	58
# 6.2.3.1.2	Provisioning of the IRI-POI, IRI-TF and CC-TF in the SMF	58
# 6.2.3.1.3	Provisioning of the MDF2	59
# 6.2.3.1.4	Provisioning of the MDF3	60
# 6.2.3.2	Generation of xIRI at IRI-POI in SMF over LI_X2	61
# 6.2.3.2.1	General	61
# 6.2.3.2.2	PDU session establishment	62
# 6.2.3.2.3	PDU session modification	67
# 6.2.3.2.4	PDU session release	69
# 6.2.3.2.5	Start of interception with an established PDU session	70
# 6.2.3.2.6	SMF unsuccessful procedure	74
# 6.2.3.2.7	MA PDU sessions	75
# 6.2.3.2.8	PDU to MA PDU session modification	88
# 6.2.3.3	Triggering of the CC-POI from CC-TF over LI_T3	89
# 6.2.3.3.1	LI_T3 interface specifics	89
# 6.2.3.3.2	CC interception with multi-homed PDU session	91
# 6.2.3.3.3	CC Interception only at PDU Session Anchor UPFs	92
# 6.2.3.4	IRI-POI in UPF triggering over LI_T2	92
# 6.2.3.5	Generation of xIRI at UPF over LI_X2	93
# 6.2.3.5.1	Packet data header reporting	93
# 6.2.3.5.2	Fragmentation	93
# 6.2.3.5.3	Packet Data Header Report (PDHR)	93
# 6.2.3.5.4	Packet Data Summary Report (PDSR)	93
# 6.2.3.6	Generation of xCC at CC-POI in the UPF over LI_X3	93
# 6.2.3.7	Generation of IRI over LI_HI2	94
# 6.2.3.8	Generation of CC over LI_HI3	95
# 6.2.3.9	Packet header information reporting	95
# 6.2.3.9.1	General	95
# 6.2.3.9.2	Provisioning details	96
# 6.2.3.9.3	PDHeaderReport record	96
# 6.2.3.9.4	PDSummaryReport record	97
# 6.2.3.10	Sharing LI state information over LI_ST	101
# 6.2.3.10.1	Overview	101
# 6.2.3.10.2	Storing LI state	101
# 6.2.3.10.3	Retrieving LI state	102
# 6.2.3.10.4	Removing LI state	102
# 6.2.4	LI at UDM for 5G	102
# 6.2.4.1	General description	102
# 6.2.5	LI at SMSF	102
# 6.2.5.1	Provisioning over LI_X1	102
# 6.2.5.2	Generation of xIRI over LI_X2	104
# 6.2.5.3	SMS Message	104
# 6.2.5.4	Generation of IRI over LI_HI2	107
# 6.2.6	LI support at NRF	107
# 6.3	4G	107
# 6.3.1	General	107
# 6.3.2	LI at MME	108
# 6.3.2.1	Provisioning over LI_X1	108
# 6.3.2.2	Generation of xIRI over LI_X2	109
# 6.3.2.2.1	General	109
# 6.3.2.2.2	MME identifier association	109
# 6.3.2.2.3	Attach	110
# 6.3.2.2.4	Detach	111
# 6.3.2.2.5	Tracking Area/EPS Location update	112
# 6.3.2.2.6	Start of interception with EPS attached UE	113
# 6.3.2.2.7	MME unsuccessful procedure	114
# 6.3.2.2.8	Positioning info transfer	115
# 6.3.2.3	Generation of IRI over LI_HI2	116
# 6.3.2.3.1	General	116
# 6.3.2.3.2	Option A	116
# 6.3.2.3.3	Option B and Option C	117
# 6.3.3	LI at SGW/PGW and ePDG	117
# 6.3.3.0	General	117
# 6.3.3.1	Provisioning over LI_X1	117
# 6.3.3.1.1	General	117
# 6.3.3.1.2	Non-CUPS Architecture	118
# 6.3.3.1.3	CUPS Architecture	119
# 6.3.3.1.4	Provisioning of the MDF2	119
# 6.3.3.1.5	Provisioning of the MDF3	120
# 6.3.3.2	Generation of xIRI over LI_X2	121
# 6.3.3.2.1	General	121
# 6.3.3.2.2	PDU Session Establishment message reporting PDU session establishment or PDN Connection establishment	121
# 6.3.3.2.3	PDU Session Modification message reporting PDU session modification, PDN Connection modification or inter-system handover	127
# 6.3.3.2.4	PDU Session Release message reporting PDU session release, PDN Connection release	132
# 6.3.3.2.5	SMF Start of Interception with Already Established PDU Session message reporting Start of Interception with Already Established PDU Session or Start of Interception with Already Established PDN Connection	133
# 6.3.3.2.6	MA PDU Session Establishment message reporting MA PDU session establishment or PDN Connection establishment as part of an MA PDU Session	135
# 6.3.3.2.7	MA PDU Session Modification message reporting MA PDU session modification, modification of a PDN Connection associated to MA PDU session or inter-system handover	135
# 6.3.3.2.8	MA PDU Session Release message reporting MA PDU session release or the release of a PDN Connection associated to an MA PDU session	136
# 6.3.3.2.9	SMF Start of Interception with Already Established MA PDU Session message reporting Start of Interception with Already Established MA PDU Session or Start of Interception with Already Established PDN Connection associated to an MA PDU Session	136
# 6.3.3.2A	Triggering of the CC-POI from CC-TF over LI_T3	137
# 6.3.3.3	Generation of xCC at CC-POI in the SGW/PGW and ePDG over LI_X3	137
# 6.3.3.3.1	Non-CUPS architecture	137
# 6.3.3.3.2	CUPS architecture	137
# 6.3.3.4	Generation of IRI over LI_HI2	137
# 6.3.3.5	Generation of CC over LI_HI3	138
# 6.4	3G	138
# 7	Service Layer Based Interception	138
# 7.1	Introduction	138
# 7.2	Central Subscriber Management	138
# 7.2.1	General description	138
# 7.2.2	LI at UDM	138
# 7.2.2.1	General description	138
# 7.2.2.2	Provisioning over LI_X1	138
# 7.2.2.3	Generation of xIRI over LI_X2	139
# 7.2.2.3.1	General description	139
# 7.2.2.3.2	Serving system	139
# 7.2.2.3.3	Subscriber record change	139
# 7.2.2.3.4	Cancel location	141
# 7.2.2.3.5	Location information request	142
# 7.2.2.3.6	Location information result	142
# 7.2.2.3.7	UE information response	143
# 7.2.2.3.8	UE Authentication response	144
# 7.2.2.3.9	Start of Interception with UE registered at the UDM	145
# 7.2.2.4	Generation of IRI over LI_HI2	145
# 7.2.3	LI at HSS	145
# 7.2.3.1	General	145
# 7.2.3.2	 Provisioning over LI_X1	146
# 7.2.3.3	 Generation of xIRI over LI_X2	146
# 7.2.3.3.1	General description	146
# 7.2.3.3.2	Serving system	146
# 7.2.3.3.3	Start of Interception with target registered at the HSS	147
# 7.2.3.4	Generation of IRI over LI_HI2	147
# 7.3	Location	148
# 7.3.1	Lawful Access Location Services (LALS)	148
# 7.3.1.1	General description	148
# 7.3.1.2	Provisioning over LI_X1	148
# 7.3.1.2.1	Target positioning service	148
# 7.3.1.2.2	Triggered location service	149
# 7.3.1.3	Triggering over LI_T2	149
# 7.3.1.4	Generation of xIRI over LI_X2	150
# 7.3.1.5	Generation of IRI over LI_HI2	151
# 7.3.2	Cell database information reporting	151
# 7.3.2.1	General description	151
# 7.3.2.2	Delivery of cell site information over LI_HI2	151
# 7.3.3	Use of the Location structure	152
# 7.3.3.1	General description	152
# 7.3.3.2	Location structure data types	153
# 7.3.3.2.1	Simple data types for location	153
# 7.3.3.2.2	Type: Location	156
# 7.3.3.2.3	Type: LocationInfo	157
# 7.3.3.2.4	Type: UserLocation	158
# 7.3.3.2.5	Type: EUTRALocation	159
# 7.3.3.2.6	Type: NRLocation	160
# 7.3.3.2.7	Type: N3GALocation	161
# 7.3.3.2.8	Type: UTRALocation	162
# 7.3.3.2.9	Type: GERALocation	163
# 7.3.3.2.10	Type: GeographicArea	164
# 7.3.3.2.11	Type: Point	165
# 7.3.3.2.12	Type: geoCoord	165
# 7.3.3.2.13	Type: PointUncertaintyCircle	165
# 7.3.3.2.14	Type: PointUncertaintyEllipse	166
# 7.3.3.2.15	Type: UncertaintyEllipse	166
# 7.3.3.2.16	Type: Polygon	166
# 7.3.3.2.17	Type: PointAltitude	167
# 7.3.3.2.18	Type: PointAltitudeUncertainty	167
# 7.3.3.2.19	Type: EllipsoidArc	167
# 7.3.3.2.20	Enumeration: RATType	168
# 7.3.3.2.21	Type: CellInformation	168
# 7.3.3.2.22	Type: RANCGI	168
# 7.3.3.2.23	Type: TAI	168
# 7.3.3.2.24	Type: ECGI	169
# 7.3.3.2.25	Type: GlobalRANNodeID	169
# 7.3.3.2.26	Type: ANNodeID	169
# 7.3.3.2.27	Type: NgENBID	170
# 7.3.3.2.28	Type: NCGI	170
# 7.3.3.2.29	Type: IPAddr	170
# 7.3.3.2.30	Type: TNAPID	171
# 7.3.3.2.31	Type: TWAPID	171
# 7.3.3.2.32	Enumeration: W5GBANLineType	171
# 7.3.3.2.33	Enumeration: TransportProtocol	172
# 7.3.3.2.34	Type: PLMNID	172
# 7.3.3.2.35	Type: ENbID	172
# 7.3.3.2.36	Type: PositioningInfo	172
# 7.3.3.2.37	Type: LocationData	173
# 7.3.3.2.38	Type: RawMLPResponse	174
# 7.3.3.2.39	Type: VelocityEstimate	175
# 7.3.3.2.40	Type: CivicAddress	175
# 7.3.3.2.41	Type: PositioningMethodAndUsage	177
# 7.3.3.2.42	Type: GNSSPositioningMethodAndUsage	177
# 7.3.3.2.43	Type: HorizontalVelocity	177
# 7.3.3.2.44	Type: HorizontalWithVerticalVelocity	177
# 7.3.3.2.45	Type: HorizontalVelocityWithUncertainty	178
# 7.3.3.2.46	Type: HorizontalWithVerticalVelocityAndUncertainty	178
# 7.3.3.2.47	Type: LocationPresenceReport	178
# 7.3.3.2.48	Type: AMFEventArea	179
# 7.3.3.2.49	Type: RMInfo	179
# 7.3.3.2.50	Type: CMInfo	180
# 7.3.3.2.51	Enumeration: AccuracyFulfilmentIndicator	180
# 7.3.3.2.52	Enumeration: PositioningMethod	180
# 7.3.3.2.53	Enumeration: PositioningMode	181
# 7.3.3.2.54	Enumeration: GNSSID	181
# 7.3.3.2.55	Enumeration: Usage	181
# 7.3.3.2.56	Enumeration: VerticalDirection	182
# 7.3.3.2.57	Type: IMSLocation	182
# 7.3.3.2.58	Type: PANIHeaderInfo	182
# 7.3.3.2.59	Type: SIPGeolocationHeaderInfo	183
# 7.3.3.2.60	Type: SIPLocationInfo	183
# 7.3.3.2.61	Type: SIPCNIHeaderInfo	183
# 7.3.3.2.62	Type: PresenceInfo	184
# 7.3.3.2.63	Type: LADNInfo	184
# 7.3.3.2.64	 Enumeration: AMFEventType	185
# 7.3.3.2.65	 Enumeration: AccessType	185
# 7.3.3.2.66	 Enumeration: UEReachability	185
# 7.3.3.2.67	Enumeration: RMState	185
# 7.3.3.2.68	Enumeration: CMState	186
# 7.3.3.2.69	Enumeration: PresenceState	186
# 7.3.3.2.70	Type: FourGPositioningInfo	186
# 7.3.3.2.71	Type: FourGLocationInfo	187
# 7.3.3.2.72	Type: CGI	187
# 7.3.3.2.73	Type: SAI	188
# 7.3.3.2.74	Type: ESMLCCellInfo	188
# 7.3.3.2.75	Type: GERANPositioningInfo	188
# 7.3.3.2.76	Type: UTRANPositioningInfo	189
# 7.3.3.2.77	Type: EPSLocationInformation	189
# 7.3.3.2.78	Type: MMELocationInformation	189
# 7.3.3.2.79	Type: SGSNLocationInformation	190
# 7.3.3.2.80	Type: UserCSGInformation	191
# 7.3.3.2.81	Type: LAI	191
# 7.3.3.2.82	Type: RAI	192
# 7.3.3.2.83	Enumeration: CSGAccessMode	192
# 7.3.3.2.84	Enumeration: CSGMembershipIndication	192
# 7.3.3.3	 Reference datum	192
# 7.3.4	Separated location reporting	193
# 7.3.4.1	General description	193
# 7.3.5	Location acquisition	193
# 7.3.5.1	General description	193
# 7.3.5.2	Acquisition request over LI_HILA	194
# 7.3.5.3	Acquisition request over LI_XLA	194
# 7.3.5.4	Location acquisition procedure at the LARF	194
# 7.3.5.4.1	General description	194
# 7.3.5.4.2	Location acquisition procedure at the LARF in case of EPC	194
# 7.3.5.4.3	Location acquisition procedure at the LARF in case of 5GC	194
# 7.3.5.5	Location acquisition delivery via the LI_HILA	194
# 7.3.5.5.1	Location acquisition response over LI_XLA	194
# 7.3.5.5.2	Location acquisition response over LI_HILA	195
# 7.3.5.6	Location acquisition delivery via the LI_HI2	195
# 7.3.5.6.1	Provisioning of the MDF2	195
# 7.3.5.6.2	LI_X2_LA delivery	196
# 7.3.5.6.3	LI_HI2 delivery	196
# 7.3.6	Location Only Reporting	196
# 7.3.6.1	General Information	196
# 7.3.6.2	Provisioning Information	196
# 7.3.6.3	Generation of Location Only xIRI	197
# 7.3.6.3.1	General	197
# 7.3.6.3.2	Location Only xIRI in 5GS	197
# 7.3.6.3.3	Location Only xIRI in EPS	197
# 7.3.6.4	Generation of Location Only IRI	197
# 7.4	Messaging	198
# 7.4.1	Introduction	198
# 7.4.2	LI at the MMS Proxy-Relay	198
# 7.4.2.1	Provisioning over LI_X1	198
# 7.4.2.2	Generation of xIRI over LI_X2	198
# 7.4.2.3	Generation of xCC over LI_X3	198
# 7.4.2.4	MMS Record Generation Cases	198
# 7.4.3	MMS Records	199
# 7.4.3.1	MMSSend	199
# 7.4.3.2	MMSSendByNonLocalTarget	201
# 7.4.3.3	MMSNotification	203
# 7.4.3.4	MMSSendToNonLocalTarget	203
# 7.4.3.5	MMSNotificationResponse	205
# 7.4.3.6	MMSRetrieval	205
# 7.4.3.7	MMSDeliveryAck	207
# 7.4.3.8	MMSForward	207
# 7.4.3.9	MMSDeleteFromRelay	209
# 7.4.3.10	MMSMBoxStore	210
# 7.4.3.11	MMSMBoxUpload	210
# 7.4.3.12	MMSMBoxDelete	211
# 7.4.3.13	MMSDeliveryReport	211
# 7.4.3.14	MMSDeliveryReportNonLocalTarget	212
# 7.4.3.15	MMSReadReport	213
# 7.4.3.16	MMSReadReportNonLocalTarget	214
# 7.4.3.17	MMSCancel	215
# 7.4.3.18	MMSMBoxViewRequest	215
# 7.4.3.19	MMSMBoxViewResponse	216
# 7.4.3.20	MMBoxDescription	217
# 7.4.3.21	MMS Content	219
# 7.4.4	IRI and CC Generation	219
# 7.4.4.1	Generation of IRI over LI_HI2	219
# 7.4.4.2	Generation of CC over LI_HI3	219
# 7.5	PTC service	219
# 7.5.1	Introduction	219
# 7.5.1.1	Provisioning over LI_X1	220
# 7.5.1.2	Generating xIRI over LI_X2	220
# 7.5.1.3	Generation of xCC over LI_X3	220
# 7.5.2	IRI events	220
# 7.5.2.1	PTC registration	220
# 7.5.2.2	PTC session initiation	220
# 7.5.2.3	PTC session abandon attempt	221
# 7.5.2.4	PTC session start	222
# 7.5.2.5	PTC session end	223
# 7.5.2.6	PTC start of interception	224
# 7.5.2.7	PTC pre-established session	225
# 7.5.2.8	PTC instant personal alert	225
# 7.5.2.9	PTC party join	225
# 7.5.2.10	PTC party drop	226
# 7.5.2.11	PTC party hold	227
# 7.5.2.12	PTC media modification	227
# 7.5.2.13	PTC group advertisement	228
# 7.5.2.14	PTC floor control	228
# 7.5.2.15	PTC target presence	230
# 7.5.2.16	PTC participant presence	231
# 7.5.2.17	PTC list management	231
# 7.5.2.18	PTC access policy	232
# 7.5.3	IRI and CC Generation	233
# 7.5.3.1	Generation of IRI over LI_HI2	233
# 7.5.3.2	Generation of CC over LI_HI3	234
# 7.6	Identifier Association Reporting	234
# 7.6.1	General	234
# 7.6.2	ICF	234
# 7.6.2.1	General	234
# 7.6.2.2	ICF receipt of records over LI_XER	234
# 7.6.2.3	ICF Query and Response over LI_XQR	234
# 7.6.2.4	ICF Identifier Association Event Handling	234
# 7.6.3	IQF	235
# 7.6.3.1	General	235
# 7.6.3.2	IQF Query and Response over LI_HIQR	236
# 7.6.3.3	IQF Query and Response over LI_XQR	236
# 7.7	LI at NEF	236
# 7.7.1	Provisioning over LI_X1	236
# 7.7.1.1	General	236
# 7.7.1.2	Provisioning of the IRI-POI and CC-POI in NEF	236
# 7.7.2	LI for NIDD using NEF	237
# 7.7.2.1	Generation of xIRI at IRI-POI in NEF over LI_X2	237
# 7.7.2.1.1	General	237
# 7.7.2.1.2	PDU session establishment	237
# 7.7.2.1.3	PDU session modification	237
# 7.7.2.1.4	PDU session release	238
# 7.7.2.1.5	Unsuccessful procedure	238
# 7.7.2.1.6	Start of interception with established PDU session	239
# 7.7.2.2	Generation of xCC at CC-POI in NEF over LI_X3	240
# 7.7.2.3	Generation of IRI over LI_HI2	240
# 7.7.2.4	Generation of CC over LI_HI3	240
# 7.7.3	LI for device triggering	240
# 7.7.3.1	Generation of xIRI LI_X2 at IRI-POI in NEF over LI_X2	240
# 7.7.3.1.1	General	240
# 7.7.3.1.2	Device trigger	240
# 7.7.3.1.3	Device trigger replace	241
# 7.7.3.1.4	Device trigger cancellation	241
# 7.7.3.1.5	Device trigger report notification	242
# 7.7.3.2	Generation of IRI over LI_HI2	242
# 7.7.4	LI for MSISDN-less MO SMS	243
# 7.7.4.1	Generation of xIRI LI_X2 at IRI-POI in NEF over LI_X2	243
# 7.7.4.1.1	General	243
# 7.7.4.1.2	MSISDN-less MO SMS	243
# 7.7.4.2	Generation of IRI over LI_HI2	243
# 7.7.5	LI for parameter provisioning	244
# 7.7.5.1	Generation of xIRI LI_X2 at IRI-POI in NEF over LI_X2	244
# 7.7.5.1.1	General	244
# 7.7.5.1.2	Expected UE behavior update	244
# 7.7.5.2	Generation of IRI over LI_HI2	245
# 7.7.6	LI for AF session with QoS	245
# 7.7.6.1	Generation of xIRI at IRI-POI in NEF over LI_X2	245
# 7.7.6.1.1	General	245
# 7.7.6.1.2	AF session with QoS provision	245
# 7.7.6.1.3	AF session with QoS notification	246
# 7.7.6.2	Generation of IRI over LI_HI2	246
# 7.8	LI at SCEF	247
# 7.8.1	Provisioning over LI_X1	247
# 7.8.1.1	General	247
# 7.8.1.2	Provisioning of the IRI-POI and CC-POI in SCEF	247
# 7.8.2	LI for NIDD using SCEF	247
# 7.8.2.1	Generation of xIRI at IRI-POI in SCEF over LI_X2	247
# 7.8.2.1.1	General	247
# 7.8.2.1.2	SCEF PDN connection establishment	247
# 7.8.2.1.3	PDN connection update	248
# 7.8.2.1.4	PDN connection release	249
# 7.8.2.1.5	Unsuccessful procedure	250
# 7.8.2.1.6	Start of interception with established PDN connection	251
# 7.8.2.2	Generation of xCC at CC-POI in SCEF over LI_X3	251
# 7.8.2.3	Generation of IRI over LI_HI2	252
# 7.8.2.4	Generation of CC over LI_HI3	252
# 7.8.3	LI for device triggering	252
# 7.8.3.1	Generation of xIRI LI_X2 at IRI-POI in SCEF over LI_X2	252
# 7.8.3.1.1	General	252
# 7.8.3.1.2	Device trigger	252
# 7.8.3.1.3	Device trigger replacement	253
# 7.8.3.1.4	Device trigger cancellation	253
# 7.8.3.1.5	Device trigger report notification	254
# 7.8.3.2	Generation of IRI over LI_HI2	254
# 7.8.4	LI for MSISDN-less MO SMS	255
# 7.8.4.1	Generation of xIRI LI_X2 at IRI-POI in SCEF over LI_X2	255
# 7.8.4.1.1	General	255
# 7.8.4.1.2	MSISDN-less MO SMS	255
# 7.8.4.2	Generation of IRI over LI_HI2	255
# 7.8.5	LI for parameter provisioning	256
# 7.8.5.1	Generation of xIRI LI_X2 at IRI-POI in SCEF over LI_X2	256
# 7.8.5.1.1	General	256
# 7.8.5.1.2	Communication pattern update	256
# 7.8.5.2	Generation of IRI over LI_HI2	257
# 7.8.6	LI for AS session with QoS	257
# 7.8.6.1	Generation of xIRI at IRI-POI in SCEF over LI_X2	257
# 7.8.6.1.1	General	257
# 7.8.6.1.2	AS session with QoS provision	258
# 7.8.6.1.3	AS session with QoS notification	258
# 7.8.6.2	Generation of IRI over LI_HI2	259
# 7.9	LI for services encrypted by CSP-provided keys	259
# 7.9.1	LI for general AKMA-based service	259
# 7.9.1.1	General	259
# 7.9.1.2	Provisioning over LI_X1	259
# 7.9.1.2.1	General	259
# 7.9.1.2.2	Provisioning of the IRI-POI in AAnF	260
# 7.9.1.2.3	Triggering of the IRI-POI in AF	260
# 7.9.1.3	Generation of xIRI at IRI-POI in AAnF over LI_X2	261
# 7.9.1.3.1	General	261
# 7.9.1.3.2	AAnF Anchor Key Register	261
# 7.9.1.3.3	AAnF AKMA application key get	261
# 7.9.1.3.4	AAnF Start of intercept with established AKMA key material	261
# 7.9.1.3.5	AAnF AKMA context removal	262
# 7.9.1.4	Generation of xIRI at IRI-POI in generic SUPI-based AF using over LI_X2	262
# 7.9.1.4.1	General	262
# 7.9.1.4.2	AF Application key refresh	262
# 7.9.1.4.3	AF Start of intercept with established AKMA application key	262
# 7.9.1.4.4	AF Auxiliary security parameter establishment	263
# 7.9.1.4.5	AF Application key removal	263
# 7.9.1.5	Generation of IRI over LI_HI2	263
# 7.10	LI in VPLMN for IMS-based services with home-routed roaming	264
# 7.10.1	Background	264
# 7.10.2	Backward compatibility	265
# 7.10.3	HR LI Phase 1	265
# 7.10.3.1	Overview	265
# 7.10.3.2	Provisioning over LI_X1	265
# 7.10.3.2.1	General	265
# 7.10.3.2.2	Provisioning of BBIFF-C and BBIFF	265
# 7.10.3.2.3	Provisioning of LMISF-IRI	266
# 7.10.3.3	Generation of xIRI over LI_X2_LITE	266
# 7.10.3.3.1	General	266
# 7.10.3.3.2	N9HR LI	267
# 7.10.3.3.3	S8HR LI	268
# 7.10.3.4	LMISF-IRI handling of xIRIs received over LI_X2_LITE	270
# 7.10.3.4.1	Handling of xIRIs	270
# 7.10.3.4.2	Handling of the stored record	270
# 7.10.3.5	Triggering of BBIFF-U from BBIFF-C over LI_T3	270
# 7.10.3.5.1	General	270
# 7.10.3.5.2	N9HR LI	271
# 7.10.3.5.3	S8HR LI	271
# 7.10.3.6	Generation of xCC over LI_X3_LITE_S	272
# 7.10.3.6.1	BBIFF-U	272
# 7.10.3.6.2	BBIFF	273
# 7.10.3.6.3	X3 PDU format	273
# 7.10.3.7	LMISF-IRI handling of xCC received over LI_X3_LITE_S	273
# 7.10.4	HR LI Phase 2	273
# 7.10.4.1	Overview	273
# 7.10.4.2	Provisioning over LI_X1	274
# 7.10.4.2.1	General	274
# 7.10.4.2.2	Provisioning of LMISF-IRI	274
# 7.10.4.2.3	Provisioning of the MDF2	275
# 7.10.4.2.4	Provisioning of the MDF3	275
# 7.10.4.3	Generation of xIRI over LI_X2	276
# 7.10.4.3.1	General concepts	276
# 7.10.4.3.2	Target match	277
# 7.10.4.3.2.1	General	277
# 7.10.4.3.2.2	Service type of voice	277
# 7.10.4.3.2.3	Service type of messaging	277
# 7.10.4.3.3	xIRIs	278
# 7.10.4.4	Triggering of BBIFF-C from LMISF over LI_T1	278
# 7.10.4.4.1	General	278
# 7.10.4.4.2	N9HR LI	278
# 7.10.4.4.3	S8HR LI	279
# 7.10.4.5	Triggering of BBIFF-U from BBIFF-C over LI_T3	280
# 7.10.4.5.1	General	280
# 7.10.4.5.2	N9HR LI	280
# 7.10.4.5.3	S8HR LI	281
# 7.10.4.6	Generation of xCC over LI_X3_LITE_M	282
# 7.10.4.7	Generation of xCC over LI_X3	282
# 7.10.4.8	Correlation identifier	282
# 7.10.4.9	Generation of IRI over LI_HI2	283
# 7.10.4.10	Generation of CC over LI_HI3	283
# 7.11	STIR/SHAKEN and RCD/eCNAM	283
# 7.11.1	Provisioning over LI_X1	283
# 7.11.1.1	General	283
# 7.11.1.2	Provisioning of the IRI-POI in the IMS network functions	283
# 7.11.1.3	Provisioning of the MDF2	284
# 7.11.2	Generation of xIRI at IRI-POI in the IMS Network Functions over LI_X2	285
# 7.11.2.1	General	285
# 7.11.2.2	Signature generation	285
# 7.11.2.3	Signature validation	288
# 7.11.2.4	IMS Network Function that interacts with signing AS	289
# 7.11.2.5	IMS Network Function that interacts with the verification AS	290
# 7.11.3	Generation of IRI over LI_HI2	290
# 7.12	LI for IMS based services	290
# 7.12.1	General	290
# 7.12.2	Overview	291
# 7.12.2.1	General	291
# 7.12.2.2	Target type and target identifiers	291
# 7.12.2.3	Roaming considerations	291
# 7.12.2.4	Service specific aspects	292
# 7.12.2.4.1	General	292
# 7.12.2.4.2	LI for normal sessions	292
# 7.12.2.4.3	LI for redirected sessions	292
# 7.12.2.4.4	LI for conferencing	292
# 7.12.2.4.5	STIR/SHAKEN	292
# 7.12.2.4.6	RCD/eCNAM	293
# 7.12.2.5	Service scoping	293
# 7.12.2.5.1	General	293
# 7.12.2.5.2	LI for voice	293
# 7.12.2.5.3	LI for Messaging	294
# 7.12.2.5.4	LI for voice-mail	294
# 7.12.2.5.5	LI for RCS	294
# 7.12.2.5.6	LI for PTC service	294
# 7.12.2.5.7	LALS triggering	294
# 7.12.2.6	Location reporting	294
# 7.12.2.7	Deployment considerations	295
# 7.12.2.8	Identifying the intercepted IMS-based communications	295
# 7.12.2.8.1	General concepts	295
# 7.12.2.8.2	Target match	295
# 7.12.2.8.2.1	General	295
# 7.12.2.8.2.2	Session based IMS services	295
# 7.12.2.8.2.3	Session independent IMS services	296
# 7.12.2.9	Handling of correlation information	297
# 7.12.3	Provisioning over LI_X1	297
# 7.12.3.1	General	297
# 7.12.3.2	Provisioning of IRI-POI	298
# 7.12.3.2.1	Session-based IMS services	298
# 7.12.3.2.2	Session-independent IMS services	298
# 7.12.3.3	Provisioning of CC-TF	299
# 7.12.3.4	Provisioning of the MDF2	300
# 7.12.3.5	Provisioning of the MDF3	301
# 7.12.4	Generation of xIRIs over LI_X2	301
# 7.12.4.1	IRI-POIs in IMS signaling functions	301
# 7.12.4.1.1	General	301
# 7.12.4.1.2	IRI-POI in P-CSCF	302
# 7.12.4.1.2.1	Session-based IMS communications	302
# 7.12.4.1.2.2	Session-independent IMS communications	302
# 7.12.4.1.3	IRI-POI in S-CSCF	302
# 7.12.4.1.3.1	Session-based IMS communications	302
# 7.12.4.1.3.2	Session-independent IMS communications	303
# 7.12.4.1.4	IRI-POI in E-CSCF	303
# 7.12.4.1.5	IRI-POI in IBCF	303
# 7.12.4.1.5.1	Session-based IMS communications	303
# 7.12.4.1.5.2	Session-independent IMS communications	304
# 7.12.4.1.6	IRI-POI in MGCF	304
# 7.12.4.1.6.1	Session-based IMS communications	304
# 7.12.4.1.6.2	Session-independent IMS communications	304
# 7.12.4.1.7	IRI-POI in AS	304
# 7.12.4.1.7.1	Session-based IMS communications	304
# 7.12.4.1.7.2	Session-independent IMS communications	304
# 7.12.4.2	IMS records	304
# 7.12.4.2.1	IMS Message	304
# 7.12.4.2.2	Start of interception with Active IMS session	305
# 7.12.4.2.3	IMS CC Unavailable	306
# 7.12.4.3	IMS record parameters	307
# 7.12.4.3.1	Type: IMSPayload	307
# 7.12.4.3.2	 Enumeration: SessionDirection	307
# 7.12.4.3.3	 Enumeration: VoIPRoamingIndication	307
# 7.12.4.3.4	Type: SIPMessage	308
# 7.12.4.3.5	Type: SIPAccessNetworkInformation	308
# 7.12.4.3.6	Type: SIPCellularNetworkInformation	308
# 7.12.5	Triggering of CC-POI by CC-TF over LI_T3	308
# 7.12.5.1	CC-TFs in IMS signaling functions	308
# 7.12.5.1.1	General	308
# 7.12.5.1.2	CC-TF in P-CSCF	309
# 7.12.5.1.3	CC-TF in IBCF	309
# 7.12.5.1.4	CC-TF in MGCF	309
# 7.12.5.1.5	CC-TF in AS/MRFC	310
# 7.12.5.2	LI_T3 triggering details	310
# 7.12.5.2.1	 General	310
# 7.12.5.2.2	 Activation Task	311
# 7.12.5.2.2.1	Overview	311
# 7.12.5.2.2.2	Activation of CC-POI in IMS-AGW, TrGW, IM-MGW	312
# 7.12.5.2.2.3	 CC-POI in MRFP	315
# 7.12.5.2.2.4	Activation of CC-POI when media interceptions are done at both sides IMS media function	316
# 7.12.5.2.3	ModifyTask	318
# 7.12.5.2.4	DeactivateTask	319
# 7.12.6	Generation of xCC over LI_X3	319
# 7.12.6.1	General	319
# 7.12.6.2	Media capture	319
# 7.12.6.3	Payload format	320
# 7.12.6.4	Payload direction	320
# 7.12.6.5	SDP session description	320
# 7.12.6.6	Additional XID related information	321
# 7.12.7	Generation of IRI over LI_HI2	321
# 7.12.7.1	General	321
# 7.12.7.2	Handling of multiple instances of list of mediation details	321
# 7.12.7.3	Mid-session activation for additional warrants at MDF2	322
# 7.12.7.4	Location reporting	322
# 7.12.8	Generation of CC over LI_HI3	322
# 7.12.8.1	General	322
# 7.12.8.2	Handling of multiple instances of list of mediation details	322
# 7.12.8.3	Handling of additional XID related information	322
# 7.12.8.4	SDP session description	322
# 7.12.8.5	Mid-session activation for additional warrants at MDF3	323
# 7.12.9	Removal of unauthorised information from IMS record payloads	323
# 7.12.9.1	General	323
# 7.12.9.2	Removal of location information	323
# 7.12.9.2.1	General	323
# 7.12.9.2.2	P-Access-Network-Info location removal	323
# 7.12.9.2.3	Cellular-Network-Info location removal	323
# 7.12.9.2.4	Geolocation header location removal	324
# 7.12.9.2.5	Removal of location information from presence information	324
# 7.12.9.3	Removal of communications content	324
# 7.12.9.3.1	General	324
# 7.12.9.3.2	Removal of SMS content	324
# 7.12.9.3.3	Removal of text content	324
# 7.12.9.3.4	Removal of content from the Subject header field	324
# 7.13	RCS	324
# 7.13.1	Provisioning over LI_X1	324
# 7.13.1.1	General	324
# 7.13.1.2	Provisioning of the POIs and TFs in the RCS Server and the POIs in the HTTP Content Server and S-CSCF by the LIPF	325
# 7.13.1.3	Provisioning of the MDF2	325
# 7.13.1.4	Provisioning of the MDF3	326
# 7.13.2	Triggering of the IRI-POI and CC-POI in the HTTP Content Server	327
# 7.13.2.1	Triggering of the IRI-POI in the HTTP Content Server over LI_T2	327
# 7.13.2.1.1	LI_T2 interface Specifics	327
# 7.13.2.2	Triggering of the CC-POI in the HTTP Content Server over LI_T3	328
# 7.13.2.2.1	LI_T3 interface Specifics	328
# 7.13.3	Generation of xIRI at IRI-POI in the RCS Server over LI_X2	329
# 7.13.3.1	General	329
# 7.13.3.1.1	Introduction	329
# 7.13.3.1.2	Common parameters for RCS reporting	329
# 7.13.3.1.2.1	Simple types	329
# 7.13.3.1.2.2	Type: RCSIdentity	330
# 7.13.3.1.2.3	Type: RCSDestinations	330
# 7.13.3.1.2.4	Type: RCSDestination	330
# 7.13.3.2	Registration	330
# 7.13.3.2.1	 RCS registration record	330
# 7.13.3.2.2	RCS Registration parameters	331
# 7.13.3.2.2.1	Enumeration: RCSRegistrationType	331
# 7.13.3.3	RCS Message	331
# 7.13.3.3.1	RCS Message record	331
# 7.13.3.3.2	RCS Message parameters	333
# 7.13.3.3.2.1	Type: RCSMessageType	333
# 7.13.3.3.2.2	Type: RCSPayload	333
# 7.13.3.3.2.3	Type: EncapsulatedRCSPayload	333
# 7.13.3.4	Session establishment	333
# 7.13.3.5	Capability discovery	333
# 7.13.3.5.1	 RCS Capability discovery record	333
# 7.14	LI at EES	334
# 7.14.1	Provisioning over LI_X1	334
# 7.14.1.1	Provisioning of IRI-POI in EES	334
# 7.14.1.2	Provisioning of the MDF2	335
# 7.14.2	Generation of xIRI at IRI-POI in EES over LI_X2	336
# 7.14.2.1	General	336
# 7.14.2.2	EEC registration and deregistration	336
# 7.14.2.3	EAS discovery	337
# 7.14.2.4	EAS discovery subscription	338
# 7.14.2.5	EAS discovery notification	339
# 7.14.2.6	Application context relocation	339
# 7.14.2.7	Application context relocation information subscription	340
# 7.14.2.8	Application context relocation information notification	341
# 7.14.2.9	EEC context relocation	341
# 7.14.2.10	Start of interception with registered EEC	342
# 7.14.2.11	Generation of IRI over LI_HI2	342
# 7.15	LI at 5GMS AF	343
# 7.15.1	Provisioning over LI_X1	343
# 7.15.1.1	Provisioning of IRI-POI in 5GMS AF	343
# 7.15.1.2	Provisioning of the MDF2	343
# 7.15.2	Generation of xIRI over LI_X2	344
# 7.15.2.1	General	344
# 7.15.2.2	Service access information	344
# 7.15.2.3	Consumption reporting	344
# 7.15.2.4	Dynamic policy invocation	345
# 7.15.2.5	Metrics reporting	345
# 7.15.2.6	Network assistance	346
# 7.15.2.7	Unsuccessful procedure	346
# 7.15.2.8	Start of interception with already configured UE	347
# 7.15.3	Generation of IRI over LI_HI2	348
# Annex A (normative): ASN.1 Schema for the Internal and External Interfaces	349
# Annex B (normative): LI Notification	349
# Annex C (normative): XSD Schema for LI_X1 extensions	350
# Annex D (informative): Drafting Guidance	350
# D.1	Introduction	350
# D.2	Drafting conventions	351
# D.3	Naming conventions	351
# D.4	ASN.1 Syntax conventions	352
# Annex E (normative): XSD Schema for Identity Association	353
# Annex F (normative): ASN.1 Schema for LI_XER messages	353
# Annex G: Void		353
# Annex H (normative): XSD Schema for State Transfers	353
# Annex I (normative): XSD Schema for Location Acquisition	353
# Annex L (normative): XSD Schema for LI Queries	353
# Annex M (normative): Reuse of externally defined structures	354
# M.1	Encapsulated Information	354
# M.1.1	General	354
# M.1.2	Encapsulated information reporting parameters	354
# M.1.2.1	Simple Types for encapsulate information reporting	354
# M.1.2.2	Type: SBIType	355
# M.1.2.3	Type: XMLType	355
# M.1.2.4	Type: MIMEEntity	355
# M.1.2.5	Type: MSRPMessage	355
# M.1.2.6	Type: MIMEPartIdentifier	355
# Annex Z (informative): Change history	356
# ==================================================
#
# Chunk 3:
# Foreword
# This Technical Specification has been produced by the 3rd Generation Partnership Project (3GPP).
# The contents of the present document are subject to continuing work within the TSG and may change following formal TSG approval. Should the TSG modify the contents of the present document, it will be re-released by the TSG with an identifying change of release date and an increase in version number as follows:
# Version x.y.z
# where:
# x	the first digit:
# 1	presented to TSG for information;
# 2	presented to TSG for approval;
# 3	or greater indicates TSG approved document under change control.
# y	the second digit is incremented for all changes of substance, i.e. technical enhancements, corrections, updates, etc.
# z	the third digit is incremented when editorial only changes have been incorporated in the document.
# ==================================================
#
# Chunk 4:
# Introduction
# The present document has been produced by the 3GPP TSG SA to standardise Lawful Interception of telecommunications. The present document describes protocols and procedures for Lawful Interception based on 3GPP specifications. These protocols and procedures cover both internal 3GPP interfaces (those required to intercept communications and manage interception within a 3GPP network) and external handover interfaces (those used for delivery of intercepted communications to Law Enforcement, or handling of warrants).
# Lawful Interception needs to be done in accordance with the applicable national or regional laws and technical regulations. Such national laws and regulations define the extent to which capabilities in the present document are applicable in specific jurisdictions.
# ==================================================
#
# Remaining Text Sections:
# Chunk 5:
# 1	Scope
# The present document specifies the protocols and procedures required to perform Lawful Interception within a 3GPP network. The present document addresses both internal interfaces used internally with a 3GPP network and external handover interfaces used to handover intercepted communications to law enforcement.
# The present document describes the detailed targeting of communications in each point of interception within a 3GPP network and the information that a point of interception needs to be able to capture. Furthermore, the detailed data formats for both the internal and external interfaces are also defined.
# National regulations determine the applicable set of information that needs to be handed over or excluded from handover to law enforcement for a given 3GPP operator service.
# ==================================================
# Chunk 6:
# 2	References
# The following documents contain provisions which, through reference in this text, constitute provisions of the present document.
# -	References are either specific (identified by date of publication, edition number, version number, etc.) or non-specific.
# -	For a specific reference, subsequent revisions do not apply.
# -	For a non-specific reference, the latest version applies. In the case of a reference to a 3GPP document (including a GSM document), a non-specific reference implicitly refers to the latest version of that document in the same Release as the present document.
# [1]	3GPP TR 21.905: "Vocabulary for 3GPP Specifications".
# [2]	3GPP TS 23.501: "System Architecture for the 5G System".
# [3]	3GPP TS 33.126: "Lawful Interception Requirements".
# [4]	3GPP TS 23.502: "Procedures for the 5G System; Stage 2".
# [5]	3GPP TS 33.127: "Lawful Interception (LI) Architecture and Functions".
# [6]	ETSI TS 103 120: "Lawful Interception (LI); Interface for warrant information".
# [7]	ETSI TS 103 221-1: "Lawful Interception (LI); Internal Network Interfaces; Part 1: X1".
# [8]	ETSI TS 103 221-2: "Lawful Interception (LI); Internal Network Interfaces; Part 2: X2/X3".
#  [9]	ETSI TS 102 232-1: "Lawful Interception (LI); Handover Interface and Service-Specific Details (SSD) for IP delivery; Part 1: Handover specification for IP delivery".
# [10]	ETSI TS 102 232-7: "Lawful Interception (LI); Handover Interface and Service-Specific Details (SSD) for IP delivery; Part 7: Service-specific details for Mobile Services".
# [11]	3GPP TS 33.501: "Security Architecture and Procedures for the 5G System".
# [12]	3GPP TS 33.108: "3G security; Handover interface for Lawful Interception (LI)".
# [13]	3GPP TS 24.501: "Non-Access-Stratum (NAS) protocol for 5G System (5GS)".
# [14]	3GPP TS 24.007: "Mobile radio interface signalling layer 3; General Aspects".
# [15]	3GPP TS 29.244: "Interface between the Control Plane and the User Plane nodes".
# [16]	3GPP TS 29.502: "5G System; Session Management Services; Stage 3".
# [17]	3GPP TS 29.571: "5G System; Common Data Types for Service Based Interfaces; Stage 3".
# [18]	3GPP TS 23.040: "Technical realization of the Short Message Service (SMS)".
# [19]	3GPP TS 23.003: "Numbering, addressing and identification ".
# [20]	OMA-TS-MLP-V3_5-20181211-C: "Open Mobile Alliance; Mobile Location Protocol, Candidate Version 3.5", https://www.openmobilealliance.org/release/MLS/V1_4-20181211-C/OMA-TS-MLP-V3_5-20181211-C.pdf.
# [21]	3GPP TS 29.540: "5G System; SMS Services; Stage 3".
# [22]	3GPP TS 29.518: "5G System; Access and Mobility Management Services; Stage 3".
# [23]	3GPP TS 38.413: "NG Application Protocol (NGAP)".
# [24]	3GPP TS 29.572: "Location Management Services; Stage 3".
# [25]	3GPP TS 29.503: "5G System; Unified Data Management Services".
# [26]	IETF RFC 815: "IP datagram reassembly algorithms".
# [27]	IETF RFC 2460: "Internet Protocol, Version 6 (IPv6) Specification".
# [28]	IETF RFC 793: "Transmission Control Protocol".
# [29]	IETF RFC 768: "User Datagram Protocol".
# [30]	IETF RFC 4340: "Datagram Congestion Control Protocol (DCCP)".
# [31]	IETF RFC 4960: "Stream Control Transmission Protocol".
# [32]	IANA (www.iana.org): Assigned Internet Protocol Numbers, "Protocol Numbers".
# [33]	IETF RFC 6437: "IPv6 Flow Label Specification".
# [34]	IETF RFC 791: "Internet Protocol".
# [35]	Open Geospatial Consortium OGC 05-010: "URNs of definitions in ogc namespace".
# [36]	3GPP TS 33.107: "3G security; Lawful interception architecture and functions".
# [37]	3GPP TS 37.340: "Evolved Universal Radio Access (E-UTRA) and NR-Multi-connectivity; Stage 2".
# [38]	3GPP TS 36.413: "S1 Application Protocol (S1AP)".
# [39]	OMA-TS-MMS_ENC-V1_3-20110913-A: "Multimedia Messaging Service Encapsulation Protocol".
# [40]	3GPP TS 23.140: "Multimedia Messaging Protocol. Functional Description. Stage 2".
# [41]	3GPP TS 38.415: "NG-RAN; PDU Session User Plane Protocol".
# [42]	3GPP TS 23.273: "5G System (5GS) Location Services (LCS); Stage 2".
# [43]	IETF RFC 4566: "SDP: Session Description Protocol".
# [44]	3GPP TS 24.193: "Stage 3: Access Traffic Steering, Switching and Splitting (ATSSS)".
# [45]	3GPP TS 29.509: "5G System; Authentication Server Services; Stage 3".
# [46]	3GPP TS 24.011: "Point-to-Point (PP) Short Message Service (SMS) support on mobile radio interface".
# [47]	3GPP TS 29.002: "Mobile Application Part (MAP) specification".
# [48]	3GPP TS 29.504: "5G System; Unified Data Repository Services; Stage 3".
# [49]	3GPP TS 29.505: "5G System; Usage of the Unified Data Repository services for Subscription Data; Stage 3".
# [50]	3GPP TS 23.401 "General Packet Radio Service (GPRS) enhancements for Evolved Universal Terrestrial Radio Access Network (E-UTRAN) access".
# [51]	3GPP TS 24.301 "Non-Access-Stratum (NAS) protocol for Evolved Packet System (EPS), Stage 3".
# [52]	3GPP TS 23.271 "Functional stage 2 description of Location Services (LCS)".
# [53]	3GPP TS 29.172 "Evolved Packet Core (EPC) LCS Protocol (ELP) between the Gateway Mobile Location Centre (GMLC) and the Mobile Management Entity (MME); SLg interface".
# [54]	3GPP TS 29.171 "LCS Application Protocol (LCS-AP) between the Mobile Management Entity (MME) and Evolved Serving Mobile Location Centre (E-SMLC); SLs interface".
# [55]	3GPP TS 24.379: "Mission Critical Push to Talk (MCPTT) call control; protocol specification".
# [56]	OMA-TS-PoC-System_Description-V2_1-20110802-A: "OMA PoC System Description".
# [57]	3GPP TS 29.541: "5G System; Network Exposure (NE) function services for Non-IP Data Delivery (NIDD); Stage 3".
# [58]	3GPP TS 29.522: "5G System; Network Exposure Function Northbound APIs; Stage 3".
# [59]	3GPP TS 29.338: "Diameter based protocols to support Short Message Service (SMS) capable Mobile Management Entities (MMEs); Stage 3".
# [60]	3GPP TS 29.337: "Diameter-based T4 interface for communications with packet data networks and applications".
# [61]	3GPP TS 24.250: "Protocol for Reliable Data Service; Stage 3".
# [62]	3GPP TS 29.128: "Mobility Management Entity (MME) and Serving GPRS Support Node (SGSN) interfaces for interworking with packet data networks and applications".
# [63]	3GPP TS 29.122: "T8 reference point for Northbound APIs".
# [64]	3GPP TS 29.598: "5G System; Unstructured Data Storage Services; Stage3".
# [65]	3GPP TS 33.535: "Authentication and Key Management for Applications (AKMA) based on 3GPP credentials in the 5G System (5GS)".
# [66]	IETF RFC 5246: "The Transport Layer Security (TLS) Protocol Version 1.2".
# [67]	GSMA IR.88: "IR.88 LTE and EPC Roaming Guidelines".
# [68]	GSMA NG.114 "IMS Profile for Voice, Video and Messaging over 5GS".
# [69]	IETF RFC 8225: "PASSporT: Personal Assertion Token".
# [70]	IETF RFC 8224: "Authenticated Identity Management in the Session Initiation Protocol (SIP)".
# [71]	IETF RFC 8588: "Personal Assertion Token (PaSSporT) Extension for Signature-based Handling of Asserted information using toKENs (SHAKEN)".
# [72]	3GPP TS 24.196: "Enhanced Calling Name (eCNAM)".
# [73]	IETF draft-ietf-stir-passport-rcd-17: "PASSporT Extension for Rich Call Data".
# NOTE:	The above document cannot be formally referenced until it is published as an RFC.
# [74]	3GPP TS 24.229: "IP multimedia call control protocol based on Session Initiation Protocol (SIP)and Session Description Protocol (SDP); Stage 3".
# [75]	IANA Session Initiation Protocol (SIP) Parameters: https://www.iana.org/assignments/sip-parameters/sip-parameters.xhtml
# [76]	IETF RFC 8946: "Personal Assertion Token (PASSporT) Extension for Diverted Calls".
# [77]	3GPP TS 23.204: "3rd Generation Partnership Project; Technical Specification Group Services and System Aspects; Support of Short Message Service (SMS) over generic 3GPP Internet Protocol (IP) access; Stage 2".
# [78]	GSMA RCC.07: "Rich Communication Suite – Advanced Communications Services and Client Specification".
# [79]	IETF RFC 4975: "The Message Session Relay Protocol (MSRP)".
# [80]	IETF RFC 3862: "Common Presence and Instant Messaging (CPIM): Message Format".
# [81]	IETF RFC 5438: "Instant Message Disposition Notification (IMDN)".
# [82]	OMA-TS-CPM_System_Description-V2_2-20170926-C: "OMA Converged IP Messaging System Description".
# [83]	Void.
# [84]	3GPP TS 36.455: "Evolved Universal Terrestrial Radio Access (E-UTRA); LTE Positioning Protocol A (LPPa) ".
# [85]	3GPP TS 37.355: "LTE Positioning Protocol (LPP)".
# [86]	3GPP TS 38.455: "NG-RAN; NR Positioning Protocol A (NRPPa)".
# [87]	3GPP TS 29.274: "3GPP Evolved Packet System (EPS); Evolved General Packet Radio Service (GPRS) Tunnelling Protocol for Control plane (GTPv2-C); Stage 3".
# [88]	3GPP TS 29.513: "5G System; Policy and Charging Control signalling flows and QoS parameter mapping".
# [89]	3GPP TS 29.512: "5G System; Session Management Policy Control Service; Stage 3".
# [90]	3GPP TS 29.508: "5G System; Session Management Event Exposure Service; Stage 3".
# [91]	3GPP TS 29.514: "5G System; Policy Authorization Service; Stage 3".
# [92]	3GPP TS 29.214: "Policy and Charging Control over Rx reference point".
# [93]	3GPP TS 24.558: "Enabling Edge Applications; Protocol specification".
# [94]	3GPP TS 29.558: "Enabling Edge Applications; Application Programming Interface (API) specification".
# [95]	3GPP TS 24.008: "Mobile radio interface Layer 3 specification; Core network protocols; Stage 3".
# [96]	3GPP TS 29.551: "5G System; Packet Flow Description Management Service; Stage 3".
# [97]	ETSI TS 103 280: "Lawful Interception (LI); Dictionary for common parameters".
# [98]	3GPP TS 26.512: "5G Media Streaming (5GMS); Protocols".
# [99]	3GPP TS 26.247: "Transparent end-to-end Packet-switched Streaming Service (PSS); Progressive Download and Dynamic Adaptive Streaming over HTTP (3GP-DASH)".
# [100]	3GPP TS 29.563: "5G System; Home Subscriber Server (HSS) services for interworking with Unified Data Management (UDM); Stage 3".
# [101]	3GPP TS 29.562: "5G System; Home Subscriber Server (HSS) Services; Stage 3".
# [102]	3GPP TS 24.341 "Support of SMS over IP networks, Stage 3".
# [103]	3GPP TS 38.473 "NG-RAN;F1 application protocol (F1AP)".
# [104]	3GPP TS 23.032: "Universal Geographical Area Description (GAD)".
# [105]	ITU-T Recommendation Q.763 (1999): "Specifications of Signalling System No.7; Formats and codes".
# [106]	3GPP TS 29.272: "Mobility Management Entity (MME) and Serving GPRS Support Node (SGSN) related interfaces based on Diameter protocol".
# [107]	IETF RFC 6442: "Location Conveyance for the Session Initiation Protocol".
# [108]	Void.
# [109]	OMA-TS-CPM_Conv_Function: "OMA CPM Conversation Functions".
# [110]	IETF RFC 2045: "Multipurpose Internet Mail Extensions (MIME) Part One: Format of Internet Message Bodies".
# [111]	3GPP TS 32.299: " Telecommunication management; Charging management; Diameter charging applications".
# [112]	3GPP TS 32.423: "Telecommunication management; Subscriber and equipment trace; Trace data definition and management".
# [113]	3GPP TS 38.414: "NG-RAN; NG data transport".
# [114]	IETF RFC 2045: "Multipurpose Internet Mail Extensions (MIME) Part One: Format of Internet Message Bodies".
# [115]	IETF RFC 5322: "Internet Message Format".
# [116]	IETF RFC 4975: "The Message Session Relay Protocol (MSRP)".
# [117]	IETF RFC 6901: "JavaScript Object Notation (JSON) Pointer".
# [118]	IETF RFC 3261: "SIP: Session Initiation Protocol".
# [119]	W3C Recommendation: "XML Path Language (XPath)".
# [120]	IETF RFC 2046: "Multipurpose Internet Mail Extensions (MIME) Part Two: Media Types".
# [121]	3GPP TR 33.928: "ADMF Logic for Provisioning Lawful Interception (LI) ".
# ==================================================
# Chunk 7:
# 3	Definitions, symbols and abbreviations
# ==================================================
# Chunk 8:
# 3.1	Definitions
# For the purposes of the present document, the terms and definitions given in 3GPP TR 21.905 [1] and the following apply. A term defined in the present document takes precedence over the definition of the same term, if any, in 3GPP TR 21.905 [1].
# ==================================================
# Chunk 9:
# 3.2	Symbols
# For the purposes of the present document, the following symbols apply:
# <symbol>	<Explanation>
# ==================================================
# Chunk 10:
# 3.3	Abbreviations
# For the purposes of the present document, the abbreviations given in 3GPP TR 21.905 [1] and the following apply. An abbreviation defined in the present document takes precedence over the definition of the same abbreviation, if any, in 3GPP TR 21.905 [1].
#
# ADMF	LI Administration Function
# CC	Content of Communication
# CSP	Communication Service Provider
# CUPS	Control and User Plane Separation
# DNAI	Data Network Access Identifier
# ICF	Identity Caching Function
# IEF	Identity Event Function
# IQF	Identity Query Function
# IRI	Intercept Related Information
# LAF	Location Acquisition Function
# LALS 	Lawful Access Location Services
# LARF	Location Acquisition Requesting Function
# LEA	Law Enforcement Agency
# LEMF	Law Enforcement Monitoring Facility
# LI	Lawful Interception
# LICF	Lawful Interception Control Function
# LI_HI1	LI_Handover Interface 1
# LI_HI2	LI_Handover Interface 2
# LI_HI3	LI_Handover Interface 3
# LI_HI4	LI_Handover Interface 4
# LI_HILA	Lawful Interception Handover Interface Location Acquisition
# LI_HIQR	Lawful Interception Handover Interface Query Response
# LIPF	Lawful Interception Provisioning Function
# LIR	Location Immediate Request
# LI_SI	Lawful Interception System Information Interface
# LISSF	Lawful Interception State Storage Function
# LI_ST	Lawful Interception State Transfer Interface
# LI_X1	Lawful Interception Internal Interface 1
# LI_X2	Lawful Interception Internal Interface 2
# LI_X2_LA	Lawful Interception Internal Interface 2 Location Acquisition
# LI_X3	Lawful Interception Internal Interface 3
# LI_XEM1	Lawful Interception Internal Interface Event Management Interface 1
# LI_XER	Lawful Interception Internal Interface Event Record
# LI_XLA	Lawful Interception Internal Interface Location Acquisition
# LI_XQR	Lawful Interception Internal Interface Query Response
# LTF	Location Triggering Function
# MDF	Mediation and Delivery Function
# MDF2	Mediation and Delivery Function 2
# MDF3	Mediation and Delivery Function 3
# MDT	Minimization of Drive Test
# MM	Multimedia Message
# MMS	Multimedia Message Service
# NAT	Network Address Translation
# NPLI	Network Provided Location Information
# O&M	Operations and Management
# ...
# -	5GMS AF returns submitConsumptionReport Response (i.e. 204 No Content) in response to a submitConsumptionReport Request (i.e. POST) from the Media Session Handler in the target UE which submits a consumption report.
# Table 7.15.2.3-1: Payload for FiveGMSAFConsumptionReporting
#
# 7.15.2.4	Dynamic policy invocation
# The IRI-POI in the 5GMS AF shall generate an xIRI containing an 5GMSAFDynamicPolicyInvocation record when the IRI-POI present in the 5GMS AF detects that an 5GMS AF has received a dynamic policy from the target UE. The IRI-POI present in the 5GMS AF shall generate the xIRI for the following events (as specified in TS 26.512 [98], clause 11.5):
# -	5GMS AF returns a createDynamicPolicy Response (i.e. 201 Created) in response to a createDynamicPolicy Request (i.e. POST) from the Media Session Handler in the target UE which creates a dynamic policy resource.
# -	5GMS AF returns a retrieveDynamicPolicy Response (i.e. 20O OK) in response to a retrieveDynamicPolicy Request (i.e. GET) from the Media Session Handler in the target UE which retrieves the dynamic policy resource.
# -	5GMS AF returns an updateDynamicPolicy Response (i.e. 20O OK or 204 No Content) in response to an updateDynamicPolicy Request (i.e. PUT) from the Media Session Handler in the target UE which replaces the dynamic policy resource.
# -	5GMS AF returns a patchDynamicPolicy Response (i.e. 20O OK or 204 No Content) in response to a patchDynamicPolicy Request (i.e. PATCH) from the Media Session Handler in the target UE which modifies the dynamic policy resource.
# -	5GMS AF returns a destroyDynamicPolicy Response (i.e. 204 No Content) in response to a destroyDynamicPolicy Request (i.e. DELETE) from the Media Session Handler of the target UE which deletes the dynamic policy resource.
# Table 7.15.2.4-1: Payload for FiveGMSAFDynamicPolicyInvocation
#
# 7.15.2.5	Metrics reporting
# The IRI-POI in the 5GMS AF shall generate an xIRI containing an 5GMSAFMetricsReporting record when the IRI-POI present in the 5GMS AF detects that an 5GMS AF has received a metrics report from the target UE. The IRI-POI present in the 5GMS AF shall generate the xIRI for the following event (as specified in TS 26.512 [98], clause 11.4):
# -	5GMS AF returns submitMetricsReport Response (i.e. 204 No Content) in response to a submitMetricsReport Request (i.e. POST) from the Media Session Handler in the target UE which submits a metrics report.
# Table 7.15.2.5-1: Payload for FiveGMSAFMetricsReporting
#
# 7.15.2.6	Network assistance
# The IRI-POI in the 5GMS AF shall generate an xIRI containing an FiveGMSAFNetworkAssistance record when the IRI-POI present in the 5GMS AF detects that an 5GMS AF has received a network assistance from the target UE. The IRI-POI present in the 5GMS AF shall generate the xIRI for the following events (as specified in TS 26.512 [98], clause 11.6):
# -	5GMS AF returns a createNetworkAssistanceSession Response (i.e. 201 Created) in response to a createNetworkAssistanceSession Request (i.e. POST) from the Media Session Handler in the target UE which creates a network assistance session resource.
# -	5GMS AF returns a retrieveNetworkAssistanceSession Response (i.e. 200 OK) in response to a retrieveNetworkAssistanceSession Request (i.e. GET) from the Media Session Handler in the target UE which retrieves an existing network assistance session resource.
# -	5GMS AF returns an updateNetworkAssistanceSession Response (i.e. 200 OK or 204 No Content) in response to an updateNetworkAssistanceSession Request (i.e. PUT) from the Media Session Handler in the target UE which replaces an existing network assistance session resource.
# -	5GMS AF returns a patchNetworkAssistanceSession Response (i.e. 200 OK or 204 No Content) in response to a patchNetworkAssistanceSession Request (i.e. PATCH) from the Media Session Handler in the target UE which modifies the network assistance session resource.
# -	5GMS AF returns a destroyNetworkAssistanceSession Response (i.e. 204 No Content) in response to a destroyNetworkAssistanceSession Request (i.e. DELETE) from the Media Session Handler in the target UE which deletes the network assistance session resource.
# -	5GMS AF returns a requestBitRateRecommendation Response (i.e. 200 OK) in response to a requestBitRateRecommendation Request (i.e. GET) from the Media Session Handler in the target UE which requests a bit rate recommendation for the next recommendation window.
# -	5GMS AF returns a requestDeliveryBoost Response (i.e. 200 OK) in response to a requestDeliveryBoost Request (i.e. POST) from the Media Session Handler in the target UE which requests a delivery boost.
# Table 7.15.2.6-1: Payload for FiveGMSAFNetworkAssistance
#
# 7.15.2.7	Unsuccessful procedure
# The IRI-POI in the 5GMS AF shall generate an xIRI containing a FiveGMSAFUnsuccessfulProcedure record when the IRI-POI present in the 5GMS AF detects an unsuccessful procedure or error condition for a target UE. Accordingly, the IRI-POI in the 5GMS AF generates the xIRI when any of the following events are detected:
# -	5GMS AF returns retrieveServiceAccessInformation response (i.e. 404 Not Found) in response to retrieveServiceAccessInformation request (i.e. GET) from the target UE.
# -	5GMS AF returns submitConsumptionReport Response (i.e. 400 Bad Request or 415 Unsupported Media Type) in response to a submitConsumptionReport Request (i.e. POST) from the target UE.
# -	5GMS AF returns submitMetricsReport Response (i.e. 400 Bad Request or 415 Unsupported Media Type) in response to a submitMetricsReport Request (i.e. POST) from the target UE.
# -	5GMS AF returns a createDynamicPolicy Response (i.e. 400 Bad Request or 401 Unauthorized) in response to a createDynamicPolicy Request (i.e. POST) from the target UE.
# -	5GMS AF returns a retrieveDynamicPolicy Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a retrieveDynamicPolicy Request (i.e. GET) from the target UE.
# -	5GMS AF returns an updateDynamicPolicy Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to an updateDynamicPolicy Request (i.e. PUT) from the target UE.
# -	5GMS AF returns a patchDynamicPolicy Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a patchDynamicPolicy Request (i.e. PATCH) from the target UE.
# -	5GMS AF returns a destroyDynamicPolicy Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a destroyDynamicPolicy Request (i.e. DELETE) from the target UE.
# -	5GMS AF returns a createNetworkAssistanceSession Response (i.e. 400 Bad Request or 401 Unauthorized) in response to a createNetworkAssistanceSession Request (i.e. POST) from the target UE.
# -	5GMS AF returns a retrieveNetworkAssistanceSession Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a retrieveNetworkAssistanceSession Request (i.e. GET) from the target UE.
# -	5GMS AF returns an updateNetworkAssistanceSession Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to an updateNetworkAssistanceSession Request (i.e. PUT) from the target UE.
# -	5GMS AF returns a patchNetworkAssistanceSession Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a patchNetworkAssistanceSession Request (i.e. PATCH) from the target UE.
# -	5GMS AF returns a destroyNetworkAssistanceSession Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a destroyNetworkAssistanceSession Request (i.e. DELETE) from the target UE.
# -	5GMS AF returns a requestBitRateRecommendation Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a requestBitRateRecommendation Request (i.e. GET) from the target UE.
# -	5GMS AF returns a requestDeliveryBoost Response (i.e. Either 400 Bad Request or 401 Unauthorized or 404 Not Found) in response to a requestDeliveryBoost Request (i.e. POST) from the target UE.
# Table 7.15.2.7-1: Payload for FiveGMSAFNetworkAssistance
#
# 7.15.2.8	Start of interception with already configured UE
# The IRI-POI in the 5GMS AF shall generate an xIRI containing an FiveGMSAFStartOfInterceptionWithAlreadyConfiguredUE record when the IRI-POI present in the 5GMS AF detects that interception is activated for a target UE which Media Session Handler has already been configured with the service access information.
# Table 7.15.2.8-1: Payload for FiveGMSAFStartOfInterceptionWithAlreadyConfiguredUE
# ==================================================
# Chunk 155:
# 7.15.3	Generation of IRI over LI_HI2
# When an xIRI is received over LI_X2 from the IRI-POI in the 5GMS AF, the MDF2 shall send the IRI message over LI_HI2 without undue delay. The IRI message shall contain a copy of the relevant record received from LI_X2. The record may be enriched by other information available at the MDF (e.g. additional location information).
# The timestamp field of the ETSI TS 102 232-1 [9] PSHeader structure shall be set to the time at which the 5GMS AF event was observed (i.e. the timestamp field of the xIRI).
# The IRI type parameter shall be included and coded according to table 7.14.2-19 (see ETSI TS 102 232-1 [9] clause 5.2.10).
# Table 7.15.3-1: IRI type for IRI messages
#
# The threeGPP33128DefinedIRI field (see ETSI TS 102 232-7 [10] clause 15) shall be populated with the BER-encoded IRIPayload.
# MDF2 delivers the IRI to the LEMF with GPSI as the target identity if and only if GPSI is present in the xIRI.
#
# Annex A (normative):
# ASN.1 Schema for the Internal and External Interfaces
# The ASN.1 module describing the structures used for LI_X2, LI_X3, LI_HI2 and LI_HI3 ("TS33128Payloads") is given in the file TS33128Payloads.asn which accompanies the present document.
# Annex B (normative):
# LI Notification
# Based on clause 5.6 of the present document, this annex defines a system of management notification of LI system with the LI_HI4 interface.
# The LI_HI4 interface shall be used to transport specific LI service O&M information (referred to as LI Notification) from the CSP to the LEMF. The individual parameters of the LI Notification message shall be coded using ASN.1 and the basic encoding rules (BER). The delivery of LI Notification shall be performed directly using the same mechanism as used for delivery of IRI messages over LI_HI2 and CC over LI_HI3.
# The LI Notification shall be used to send electronic notification to the LEMF in the following cases:
# 1)	after the activation of lawful interception;
# 2)	after the deactivation of lawful interception;
# 3)	after the modification of an active lawful interception.
# Table B.1-1: LINotification message
#
# Conditional parameters shall be set as follows:
#
#
#
# The individual notifications parameters shall be sent to the LEMF as soon as possible with the lowest latency at least once (if available).
# The MDF2/3 will deliver the LINotification message to LEMF.
# Annex C (normative):
# XSD Schema for LI_X1 extensions
# The XSD schema describing the extensions used for LI_X1 is given in the file urn_3GPP_ns_li_3GPPX1Extensions.xsd which accompanies the present document.
# Annex D (informative):
# Drafting Guidance
# D.1	Introduction
# This annex provides drafting guidance for contributors wishing to propose changes to the present document.
# D.2	Drafting conventions
# Table D.2-1: Drafting conventions
#
# D.3	Naming conventions
# Table D.3-1: Naming conventions
#
# ExampleBadStructure ::= SEQUENCE
# {
# 	FirstField		[1] FirstFieldType,		-- D.3.1 First letter of field is upper case
# 	secondField		[2] secondFieldType,	-- D.3.2 First letter of type is lower case
# 	3rdField		[3] 3rdFieldType,		-- D.3.3 Names starts with digit
# 	fourth-field	[4]	Fourth_Field_Type,	-- D.3.4 Names include hyphen and underscore
# 	fifthfield		[5]	Fifthfieldtype,		-- D.3.5 Names are not camelCased
# 	msisdn			[6] MSISDN,				-- D.3.6 Acronyms in field name not wholly upper-cased
# 	mSISDN			[7] Msisdn				-- D.3.6 Acronyms in type name not wholly upper-cased
# }
# Figure 1 – Naming convention counter-examples
#
# D.4	ASN.1 Syntax conventions
# Table D.4-1: ASN.1 Syntax conventions
#
# ConformantModule
# {itu-t(0) identified-organization(4) etsi(0) securityDomain(2) lawfulIntercept(2) ... }
#
# DEFINITIONS EXTENSIBILITY IMPLIED ::=
#
# BEGIN
#
#
# Structure1 ::= SEQUENCE
# {
#     field1	[1] Field1,
#     field2	[2] Field2
# }
#
# Field1 ::= ENUMERATED
# {
#     choice1(1),
#     choice2(2),
#     choice3(3)
# }
#
# Field2 ::= OCTET STRING
#
# END
# Figure 2 – Syntax convention example
# NonconformantModule
# {itu-t(0) identified-organization(4) etsi(0) securityDomain(2) lawfulIntercept(2) ... }
#
# DEFINITIONS AUTOMATIC TAGS ::=          -- D.4.1 Not declared with EXTENSIBILITY IMPLIED
#                                         -- D.4.2 Declared AUTOMATIC TAGS
# BEGIN
#
# Structure1 ::= SEQUENCE {               -- D.4.11 Braces not given their own line
#     field1  [0] ::= ENUMERATED          -- D.4.3 SEQUENCE tags don’t start at 1
#     {                                   -- D.4.5 Anonymous type used
#         choice1(0),                     -- D.4.4 ENUMERATED tag numbers don’t start at 1
#         choice2(2),
#         choice3(3)
#     },
#     field2  [2] Field2                  -- D.4.10 Field name is bold
# }
#
# Field2 ::= OCTET STRING                 -- D.4.10 Type names in definitions is bold
#
# END
# Figure 3 – Syntax convention counter-examples
# Annex E (normative):
# XSD Schema for Identity Association
# The XSD schema describing the extensions used for Identity Association is given in the file urn_3GPP_ns_li_3GPPIdentityExtensions.xsd which accompanies the present document.
# Annex F (normative):
# ASN.1 Schema for LI_XER messages
# The ASN.1 schema describing the structures used for LI_XER is given in the file TS33128IdentityAssociation.asn which accompanies the present document.
# Annex G:
# Void
# The ASN.1 schema describing the structures used for LI_XER is given in the file TS33128IdentityAssociation.asn which accompanies the present document.
# Annex H (normative):
# XSD Schema for State Transfers
# The XSD schema describing the structures used for state transfer is given in the file urn_3GPP_ns_li_3GPPStateTransfer.xsd which accompanies the present document.
# Annex I (normative):
# XSD Schema for Location Acquisition
# The XSD schema describing the structures used for Location Acquisition query extensions is given in the file urn_3GPP_ns_li_3GPPXLAExtensions.xsd which accompanies the present document.
# Annex L (normative):
# XSD Schema for LI Queries
# The XSD schema describing the structures used for LI queries is given in the file  urn_3GPP_ns_li_3GPPLIQueryExtensions.xsd which accompanies the present document.
# Annex M (normative):
# Reuse of externally defined structures
# M.1	Encapsulated Information
# M.1.1	General
# The subclauses below define LI structures to allow for the reuse of externally defined structures and schemas.
# The current version of this specification the following specific encapsulated information types are defined:
# -	SBIType for carrying messages or parameters defined by 3GPP for use over the Service Based Interfaces (SBIs).
# -	XMLTypes for carrying messages or parameters in XML.
# -	MIMEEntity for carrying MIME Entities.
# -	MSRPMessage for sending information formated in an MSRP Message.
# The encapsulated information type of the outermost layer of the encapsulated payload shall be used to report the payload.
# M.1.2	Encapsulated information reporting parameters
# M.1.2.1	Simple Types for encapsulate information reporting
# Table M.1.2.1-1: Simple Types for LI reporting of encapsulated information
#
# M.1.2.2	Type: SBIType
# Table M.1.2.2-1: Structure of the SBIType type
#
# M.1.2.3	Type: XMLType
# Table M.1.2.3-1: Structure of the XMLType type
#
# M.1.2.4	Type: MIMEEntity
# Table M.1.2.4-1: Structure of the MIMEEntity type
#
# M.1.2.5	Type: MSRPMessage
# Table M.1.2.5-1: Structure of the MSRPMessage type
#
# M.1.2.6	Type: MIMEPartIdentifier
# Table M.1.2.6-1: Structure of the MIMEPartIdentifier type
#
#
# Annex Z (informative):
# Change history
# ==================================================

# %%
#Extraction of those in chunks in several chunks in .txt with proper namings

# %%
import re
import os

# Read text from the input file
with open('/Users/aadivikram/Desktop/3GPP_extracted/output_p/extracted_text.txt', 'r') as file:
    text = file.read()

# Find the indices of the first occurrence of '3GPP TS' and 'Contents'
first_3gpp_ts = text.find('3GPP TS')
first_contents = text.find('Contents')

# Find the indices of the second occurrence of 'Foreword'
first_foreword = text.find('Foreword')
second_foreword = text.find('Foreword', first_foreword + 1)

# Find the index of the first occurrence of 'Introduction' after the second 'Foreword'
first_introduction = text.find('Introduction', second_foreword)

# Find the indices of the second occurrence of '1 Scope'
first_scope = text.find('1	Scope')
second_scope = text.find('1	Scope', first_scope + 1)


# Initialize variables for chunk text
chunk_texts = []

# Extract the first chunk between '3GPP TS' and 'Contents'
if first_3gpp_ts != -1 and first_contents != -1:
    first_chunk = text[first_3gpp_ts:first_contents]
    chunk_texts.append(first_chunk.strip())

# Extract the second chunk between 'Contents' and the second 'Foreword'
if first_contents != -1 and second_foreword != -1:
    second_chunk = text[first_contents:second_foreword]
    chunk_texts.append(second_chunk.strip())

# Extract the third chunk between the second 'Foreword' and the 'Introduction'
if second_foreword != -1 and first_introduction != -1:
    third_chunk = text[second_foreword:first_introduction]
    chunk_texts.append(third_chunk.strip())
    
# Extract the fourth chunk between the 'Introduction' and the second '1 Scope'
if first_introduction != -1 and second_scope != -1:
    fourth_chunk = text[first_introduction:second_scope]
    chunk_texts.append(fourth_chunk.strip())
    
# Extract the remaining text based on the given regex pattern
remaining_text = text[second_scope:]
sections = re.split(r'\n(?=\d+(\.\d+){0,2}\s)(?!\.\d)', remaining_text)

# Add remaining sections to the chunk_texts list
for section in sections:
    if section and section.strip() and not re.match(r'^\.?\d+\s*$', section.strip()):
        chunk_texts.append(section.strip())

# Create a directory to store chunk files
output_directory = '/Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files'
os.makedirs(output_directory, exist_ok=True)

# Write chunks to individual text files, limited to the first three chunks
for i, chunk_text in enumerate(chunk_texts[:4], start=1):
    lines = chunk_text.strip().split('\n')
    first_line = lines[0].strip()
    if first_line:  # If the first line is not empty
        chunk_name = first_line.replace('/', '_')
    else:
        chunk_name = f"Chunk_{i}"

    chunk_filename = os.path.join(output_directory, f"{chunk_name}.txt")
    with open(chunk_filename, 'w') as chunk_file:
        chunk_file.write(chunk_text)
        print(f"Created file: {chunk_filename}")
# Out:
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/3GPP TS 33.128 V18.4.0 (2023-06).txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/Contents.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/Foreword.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/Introduction.txt

# %%
import re
import os

# Read text from the input file
with open('/Users/aadivikram/Desktop/3GPP_extracted/output_p/extracted_text.txt', 'r') as file:
    text = file.read()

# Find the indices of the first occurrence of '3GPP TS' and 'Contents'
first_3gpp_ts = text.find('3GPP TS')
first_contents = text.find('Contents')

# Find the indices of the second occurrence of 'Foreword'
first_foreword = text.find('Foreword')
second_foreword = text.find('Foreword', first_foreword + 1)

# Find the indices of the second occurrence of '1 Scope'
first_scope = text.find('1	Scope')
second_scope = text.find('1	Scope', first_scope + 1)

# Initialize variables for chunk text
chunk_texts = []

# Extract the first chunk between '3GPP TS' and 'Contents'
if first_3gpp_ts != -1 and first_contents != -1:
    first_chunk = text[first_3gpp_ts:first_contents]
    chunk_texts.append(first_chunk.strip())

# Extract the second chunk between 'Contents' and the second 'Foreword'
if first_contents != -1 and second_foreword != -1:
    second_chunk = text[first_contents:second_foreword]
    chunk_texts.append(second_chunk.strip())

# Extract the third chunk between the second 'Foreword' and the second '1 Scope'
if second_foreword != -1 and second_scope != -1:
    third_chunk = text[second_foreword:second_scope]
    chunk_texts.append(third_chunk.strip())

# Extract the remaining text based on the given regex pattern
remaining_text = text[second_scope:]
sections = re.split(r'\n(?=\d+(\.\d+){0,2}\s)(?!\.\d)', remaining_text)

# Add remaining sections to the chunk_texts list
for section in sections:
    if section and section.strip() and not re.match(r'^\.?\d+\s*$', section.strip()):
        chunk_texts.append(section.strip())

# Create a directory to store chunk files
output_directory = '/Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files'
os.makedirs(output_directory, exist_ok=True)

# Write chunks to individual text files, starting from the 4th chunk
for i, chunk_text in enumerate(chunk_texts[3:], start=4):
    lines = chunk_text.strip().split('\n')
    first_line = lines[0].strip()

    # Extract section number from the first line using regex pattern
    section_number = re.match(r'^(\d+(\.\d+)*)\s', first_line)
    if section_number:
        chunk_name = section_number.group(1)
    else:
        chunk_name = f"Chunk_{i}"

    chunk_filename = os.path.join(output_directory, f"{chunk_name}.txt")
    with open(chunk_filename, 'w') as chunk_file:
        chunk_file.write(chunk_text)
        print(f"Created file: {chunk_filename}")
# Out:
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/3.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/3.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/3.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.4.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.4.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.4.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.4.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.4.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/4.4.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.2.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.2.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.2.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.2.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.2.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.2.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.2.7.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.3.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.3.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.3.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.3.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.3.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.4.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.4.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.4.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.5.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.5.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.5.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.5.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.5.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.6.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.6.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.7.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.7.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.7.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.8.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.8.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.8.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.8.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.9.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.10.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.10.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.10.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.10.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.10.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.11.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.11.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.11.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.12.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.12.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/5.12.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.2.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.2.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.2.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.2.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.2.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.2.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.3.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.3.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.3.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/6.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.2.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.2.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.2.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.3.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.3.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.3.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.3.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.3.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.3.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.4.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.4.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.4.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.4.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.5.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.5.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.5.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.6.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.6.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.6.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.7.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.7.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.7.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.7.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.7.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.7.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.7.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.8.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.8.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.8.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.8.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.8.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.8.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.8.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.9.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.9.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.10.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.10.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.10.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.10.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.10.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.11.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.11.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.11.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.11.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.4.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.5.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.6.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.7.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.8.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.12.9.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.13.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.13.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.13.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.13.3.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.14.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.14.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.14.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.15.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.15.1.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.15.2.txt
# Created file: /Users/aadivikram/Desktop/3GPP_extracted/chunk_text_files/7.15.3.txt
